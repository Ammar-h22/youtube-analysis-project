# %%
from googleapiclient.discovery import build 
import pandas as pd
import seaborn as sns

# %%
api_key = 'ENTER YOUR API KEY'
# channel_id = 'UCeVMnSShP_Iviwkknt83cww'  # CodeWithHarry
channel_ids = ['UCOhHO2ICt0ti9KAh-QHvttQ' , # Technical Guruji
               'UCdp6GUwjKscp5ST4M4WgIpw',  # TechWiser
               'UCXUJJNoP1QupwsYIWFXmsZg',  # Tech Burner
               'UCEPL07qzVsOcHd3sMUws65g',  # Trakin Tech
               'UCdoDYkupTElV62K7ttA_E4w']  # TechBar

youtube = build('youtube', 'v3', developerKey=api_key)   # Created the Youtube service

# %% [markdown]
# ## Function to get channel statistics

# %%
# def get_channel_stats(youtube, channel_id):
    
#    request = youtube.channels().list(
#        part='snippet,contentDetails,statistics',
#        id=channel_id)
#    response = request.execute()

#    data = dict(Channel_name = response['items'][0]['snippet']['title'],
#                Subscribers = response['items'][0]['statistics']['subscriberCount'],
#                Views = response['items'][0]['statistics']['viewCount'],
#                Total_videos = response['items'][0]['statistics']['videoCount'])
    
#    return data

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []  # Empty list
    
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids))   # Because we cannot pass here list, so we converted it to string.
    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    return all_data
    # return response

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)
channel_statistics
# Out:
# [{'Channel_name': 'TechWiser',
#   'Subscribers': '2140000',
#   'Views': '556804268',
#   'Total_videos': '1171',
#   'playlist_id': 'UUdp6GUwjKscp5ST4M4WgIpw'},
#  {'Channel_name': 'Technical Guruji',
#   'Subscribers': '23500000',
#   'Views': '3696495805',
#   'Total_videos': '5481',
#   'playlist_id': 'UUOhHO2ICt0ti9KAh-QHvttQ'},
#  {'Channel_name': 'TechBar',
#   'Subscribers': '4890000',
#   'Views': '1325638297',
#   'Total_videos': '1409',
#   'playlist_id': 'UUdoDYkupTElV62K7ttA_E4w'},
#  {'Channel_name': 'Trakin Tech',
#   'Subscribers': '14400000',
#   'Views': '2657535673',
#   'Total_videos': '3951',
#   'playlist_id': 'UUEPL07qzVsOcHd3sMUws65g'},
#  {'Channel_name': 'Tech Burner',
#   'Subscribers': '11700000',
#   'Views': '2099374548',
#   'Total_videos': '1307',
#   'playlist_id': 'UUXUJJNoP1QupwsYIWFXmsZg'}]

# %%
# Using Pandas:
channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#        Channel_name Subscribers       Views Total_videos  \
# 0         TechWiser     2140000   556804268         1171
# 1  Technical Guruji    23500000  3696495805         5481
# 2           TechBar     4890000  1325638297         1409
# 3       Trakin Tech    14400000  2657535673         3951
# 4       Tech Burner    11700000  2099374548         1307
#
#                 playlist_id
# 0  UUdp6GUwjKscp5ST4M4WgIpw
# 1  UUOhHO2ICt0ti9KAh-QHvttQ
# 2  UUdoDYkupTElV62K7ttA_E4w
# 3  UUEPL07qzVsOcHd3sMUws65g
# 4  UUXUJJNoP1QupwsYIWFXmsZg

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# playlist_id     object
# dtype: object

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set({'figure.figsize': (6, 4)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %% [markdown]
# **Function to get video ids**

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Tech Burner', 'playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UUXUJJNoP1QupwsYIWFXmsZg'

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
        part = 'contentDetails',
        playlistId = playlist_id,
        maxResults = 50)
    response = request.execute()

    video_ids = []

    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True

    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                part = 'contentDetails',
                playlistId = playlist_id,
                maxResults = 50,
                pageToken = next_page_token)
            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            next_page_token = response.get('nextPageToken')
    
    return video_ids
    # return response

# %% [markdown]
# Note that YouTube service will only give 5 values bydefault, And we can extract maximum 50 values using maxResults parameter. So we need to write some logic to extract all the video_ids from a particular channel. (Logic is written above)

# %%
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ['NjoqMPsIioY',
#  'UsBR_KfQG5s',
#  'rXKhzWFlYW8',
#  'G86hGrhB5tw',
#  '8nc9QG-Ljvo',
#  'HdpgOBrthOY',
#  '4wrZtlXEp0o',
#  'hzs4iAkNtWU',
#  'Qq5BCbL2WEs',
#  'IANPKUiltuU',
#  'K1Ov6HHIf48',
#  'CaHXs7x8ty8',
#  '7nNnudgt2hU',
#  'GvL46rnAXYE',
#  'kpV8ITBCuQ4',
#  'XW2Lxuv-f1g',
#  '_wsimG1B5Q4',
#  'twZNsoDkJvc',
#  'MzcQE2N65MI',
#  'GOTGaOzJYEI',
#  'I6upHAy5HSw',
#  'unTr-Od-7D8',
#  'TDvjEc7FCic',
#  'Gj7LUVIVPpI',
#  '9S7Ng6mPQaw',
#  '2zhUebETcUI',
#  '7MQ2hLLoHZY',
#  'Lhu10K0lQ5k',
#  'FM_nepotbw4',
#  'aJabku0cPC4',
#  '_uq2MwOXpxU',
#  'kEIUeS9BhdI',
#  '5oDlPjpWatA',
#  'ca3olsISV04',
#  'DVtzFSN7jp8',
#  'gs22E2n6WLo',
#  'qg0NuvSsLkY',
#  'CKmPvmDXPG8',
#  '8j9jD58X774',
#  'UHtKXa7Rxnw',
#  'p05vyNIPpD0',
#  'bnJw9v0YN34',
#  'KvzzhAzOKt8',
#  '752VrWuZ-vY',
#  'wCdhxZ9fsXI',
#  'q3v0Tyt3oCQ',
#  'kf3M6MBF9CM',
#  '1NFa83qUm4o',
#  'JHUYZVfWVF8',
#  'Lzq-2r6ah-g',
#  '3ub-l8pYmdQ',
#  'djJKuJdo51I',
#  'XoBFrihBwSM',
#  'ACr64Eu82JE',
#  '5uOLxAcihOw',
#  '0oH-r1kUxCk',
#  'gL-Ydo-5HDw',
#  'JGHtSc63WPM',
#  'VAuyLN5ILHw',
#  'eXbVpXvkKsg',
#  'ScWfuoXPk2o',
#  'incKwx85axg',
#  '2wm7096d6KA',
#  'hzUD9Zeg6kQ',
#  'ROAKqLtm6Zw',
#  'ZWAfEcUM7tY',
#  'J40iAd46LEk',
#  'mgwhJVpFdqg',
#  '0T1x7c_-z0A',
#  'AefDClwKYRs',
#  'F6hmwkI3n64',
#  'AmFrzQV074w',
#  'kLUFBgk6Ows',
#  '6Jcg9twNuG0',
#  'YiNFmIarXJE',
#  '9ZTu_aOSmfg',
#  'rEpIuJDDAZI',
#  'kjQfuMS9dSs',
#  'aDEmS10brlc',
#  'STuiGCfBWc8',
#  'LFxnAW6t8lI',
#  'L-gu52eVHhk',
#  'vCBO8dpNDRo',
#  'hroirymskWU',
#  'ZByGE8aNsIc',
#  'bMB2oz8nJQI',
#  'roJecXdxZqQ',
#  'RqmwLMwNumo',
#  'R2wP_KUSB10',
#  'TQCaVkqkJic',
#  'yzHPPgQUvR0',
#  '-f-qV-t0_x0',
#  'igVy-u6Pg-Q',
#  'JggPXfbg0Is',
#  '5RiOhu2KedU',
#  'ZvEbVu3czfE',
#  'CAWVA2L2gu0',
#  '4MfCtzzMRPY',
#  'w9_8GImMUDc',
#  'OHjneIupETI',
#  'W4o56ye3plw',
#  'SjcPR2E4yE4',
#  '3KDpEZQ33sM',
#  '5S_QOK9UP2M',
#  'V-yXd9RA2Ho',
#  'HD3IwKkRGJE',
#  '4qVRFgRcFkk',
#  'wzPZKVOoBUc',
#  '5aFgJpL1mBw',
#  'rQBHVB5Tgmw',
#  '2jJN88y3F_g',
#  'cZSrDDmW3tU',
#  'lbyhSmtou7E',
#  'RVRQ7IemAlo',
#  'wLwFCDyUyVs',
#  'dm7BSM7Y1z4',
#  'xf5zCgdanPE',
#  'meSQdxKaBjk',
#  '-oQA7G6spsU',
#  'NOE-QhB2JOI',
#  'PvoQlnVCO0g',
#  'ZnW46VZgxew',
#  'XZz0Jp0fpUg',
#  'vMv2IpGqXDo',
#  '5ml7LtbGIvU',
#  'kdKAwh_gvDc',
#  'SRKomjJwzas',
#  '_A1dVW0J6go',
#  'uBfDCsRVlJQ',
#  'OOvMct1QsCk',
#  '2lSkqOH1pMo',
#  'HY2e-bW0jO0',
#  'FT0_Fpe1Et0',
#  'whpRykY0Fu0',
#  'b3-gdDnybIg',
#  '-DL5DYg8La4',
#  'Bbksc17GIQc',
#  'PqqwTBKYusU',
#  'UjMkvDZJwuI',
#  'sYr2PChHZcc',
#  'E7XiJ1hZ_pc',
#  'Mf5kdmW7oWo',
#  'FiBL5k5eCqw',
#  'Crl5g36MapE',
#  'B3jHItsUOcA',
#  'G6dd1BHmO-A',
#  'adM28WMGCuo',
#  'W_dF07JvrJo',
#  'h_JcE0yHkDo',
#  'kWXhPrAy-1s',
#  'X0JtzEi2L0U',
#  'bPSImaOZwXY',
#  '5FKy4usrzEQ',
#  'cxTw_I8BIs0',
#  'NrrhpjnSZwE',
#  'mstlDn8MxF8',
#  'aWg8nxBxPsY',
#  'd_WL4W-S6Ok',
#  'vLZ1QyB9BNk',
#  'sUjCrIfBEPY',
#  'BSA51TU9yhg',
#  '8Jlsig7O7No',
#  'RiPU87LcA2g',
#  'DmLF7bcf4tg',
#  '97xEuTy0VhU',
#  'lq95-abYMqY',
#  '0_xGcxHHZy0',
#  'vcNl1XcSILg',
#  'rGAzWTf68nI',
#  '5ufOQ1VB1bM',
#  'ZWOMXidhRbI',
#  'h8YE0e3j50A',
#  '4cVjARugnoM',
#  '2xuXQLtA4Fo',
#  'lbjafhTk6Ow',
#  'aK_IE2ZPXjw',
#  'PdPKMddLHmw',
#  'Sk6wPiMa5LU',
#  'uTCSd3NsoAA',
#  '0S0hCzau_YU',
#  'aiODQWYFMa0',
#  '-rIy5QlI5L8',
#  'TORfAEp8AUs',
#  'UuLQtVUrOEc',
#  'ama3qvvwDx0',
#  'v8V93KFxrOI',
#  'X2dh1Ps1Oyc',
#  '1VBq_JtgIeI',
#  'cCYObFBEp0k',
#  'd6Db53YWGlc',
#  'KLvlUH2SFfI',
#  'ge2xHEeogrk',
#  '5RQswm2zeIE',
#  'PNBsbaZ3dZk',
#  'LzGzrOm7EP0',
#  '-Vn03957h0U',
#  'aywEawmDa4s',
#  'k86ZqM34l2I',
#  'BASB47pT-2E',
#  'GrEPfmL6Ta4',
#  'qLY1tBycJwo',
#  'QnP9NCmHYYE',
#  '-l01Mz46gS8',
#  '-VuThyqV5Yo',
#  'D5nOwwgu-P4',
#  'NsCAZCwWjmY',
#  'PzPvzPNSFu4',
#  'fpKIvuzZeAA',
#  'bfLV_zWGmUw',
#  'KQ8HIIot8tQ',
#  'lszuuqoiQg4',
#  'gHHfwb6ra1I',
#  '-0fUAaeDnQM',
#  'QVemto_AyzU',
#  'nQ1_i-3LE8Y',
#  'FefdV10Lv_I',
#  'P9x21eV-kNo',
#  '_A2Og9ckM7c',
#  'Evb5Z9hNGM8',
#  't-OyxDHELFU',
#  'DLwF4F5eJc0',
#  'NMHwoZH0V3M',
#  'ZYUzHSCjXJA',
#  '55XD4JznWM8',
#  'SbrI6MPInas',
#  'Gjq-LCM85VE',
#  'Yt-rkODedRM',
#  'yzVImnZ0Ji0',
#  '5ItajkOTzkI',
#  'J9BsPDrD6nY',
#  '8yr36ejdzMc',
#  'nw2OFvZU-Vg',
#  'm6UxTDp1AKk',
#  '5vIAWGHCtHw',
#  'v9RdDJftrgU',
#  'QL8WsAeEJes',
#  'sy6FxKnKNIg',
#  'CgBRYn9avf0',
#  'zr3JN1JQeKI',
#  '_Q1IMzQCfw8',
#  'Ozyh08dYgY0',
#  'JgIXqHX2GlM',
#  'WaEV0M-vqAU',
#  'fhoEX4cDxgM',
#  'CWuGKq_kCds',
#  'DY1LEvvWu8o',
#  'oQlO8qss2VI',
#  '63iMcF0vQtY',
#  'Cy-KKK3Bn2E',
#  '3O8z9fFQx94',
#  'rE9L7v97uqI',
#  '8Q4hZ11va28',
#  'sv4YNDnUa4g',
#  'ZhZu0ypjxWU',
#  'q6hWYBqvrj0',
#  'qIq-liSj658',
#  'I168uYC2LhA',
#  'T20yRIeAeXo',
#  '8y2r-MrBy5k',
#  'bElicGtkn34',
#  'qhLEJn7ycYY',
#  'iKvMaVeYjlc',
#  '9slwlr4gsvU',
#  '2epME3sXepM',
#  'Ti56ISDsPno',
#  'uRnTOpxC2RQ',
#  'vm7GR1qiufw',
#  'Xl17bNWhf3w',
#  '8aHlhRBdVhY',
#  'HvZ1yHtlwpM',
#  'Dp75meaZohE',
#  'VcqM5Ii9YIA',
#  'hIElG-63sIs',
#  '8ezeVNbqMdM',
#  '2a32Dun8RN0',
#  'PlqeEe96PSQ',
#  'kdq4E5B3D_Y',
#  'Mp2XH7Na6vU',
#  'ugORuZbdSNE',
#  '_lxo0TLAbO0',
#  '-tj1eCR3x-M',
#  'PpYaLhGS9y4',
#  '4foujdce1zM',
#  'QRP9OHl0lOg',
#  '7tHHaNriHjs',
#  '2LePW2_NWjc',
#  'e5k0a7zWniM',
#  '61KJGalKqjM',
#  'O5TRw-AmIBY',
#  '8psk5rg-aOU',
#  'voA-VZbMg2Y',
#  'XVCgllMKnHw',
#  'oCimyqcpfvk',
#  'ql0jBCY53K8',
#  '8WEjHWb5mfE',
#  'TFsgxYGjAxY',
#  'o9tyFC208VQ',
#  '-srk_crn4YA',
#  'mtqfJYi483w',
#  'xTTo-5zipqY',
#  '_ZfQtK2VSlk',
#  'c5aKiw2GeZ8',
#  'rfm7Yp9nG-s',
#  'nrGUW64oSOs',
#  'dRCg-W5lTXU',
#  'n8B3lTjlY0Y',
#  '96JCKfc7y1o',
#  'u995Ns19CS4',
#  '1vvA0k_M2lg',
#  'ONwsfTjt2UY',
#  'vUKGFlh09Js',
#  '9q7RiLCq7nc',
#  'PdqoMrpsGAk',
#  'HJzCA-EPczg',
#  'mmEVf2ciUeY',
#  'j1kwwdJLBqQ',
#  'Sk0lz6prTTs',
#  'YQXlF-XFVWA',
#  'T2vTffqUJ3Q',
#  'bu6bCgfwUf4',
#  'aqiEIUnPYOg',
#  'Kb9FagZo-20',
#  'T7Ppsm0g2VE',
#  'cZ34wYcAGa4',
#  'dgtiTyxFgoA',
#  'rjaEojuiNvw',
#  'uy_YfJwedVM',
#  'j_18UV939DM',
#  'idS3V7e9eug',
#  'otO4ume6m-8',
#  'qpJh-9DVOL4',
#  'ffP7LKc3wTE',
#  '6xBGCbn4bWk',
#  'syh3H5xspbY',
#  'BMjUI2fN2QA',
#  'JFXzKwN_IJ8',
#  '2FKqfVfOwWs',
#  'j3BMp8prdxA',
#  'SSabLdRfoDQ',
#  'HEz8cal2Wxg',
#  'MyjixVq6rzc',
#  'vtddIgvSBao',
#  'wvPvbXthF6E',
#  'YgTzltjUbIM',
#  'aBU3OoX_6Q0',
#  '0dlrE4IRKW4',
#  'wvIrNnku-xE',
#  'jQ7sOCCUyV0',
#  '8su01mmOpi0',
#  'RD-_mGQtptI',
#  'kLjU7eD9cAo',
#  'qwUHzwN0v70',
#  'hvYDzd6oZiI',
#  'po7t_U-sLi8',
#  'U9ceqPSeHgo',
#  'BtdkTh8x0Ac',
#  'FLZmaSGNuN8',
#  'GveLFSLbRxg',
#  '7AGYDM0Ueq0',
#  '79tI4OMbwKo',
#  '1USExPyX9ds',
#  'WvBBJcZSn14',
#  'T0ZgfCL95HY',
#  'm9fPkpedSHA',
#  'PERDUsKiMgQ',
#  'KRvwospjxBg',
#  'Awu1qO_v_ks',
#  'ajg5ZjtJPWw',
#  'q6CpztZfoA8',
#  'JZAvl9Tv4fE',
#  'Wuh-Uv-k9iE',
#  'UxWTwyCRT0E',
#  'XyqCFYnZ3EU',
#  'r86oZ5vd01I',
#  'I338ZBKPScg',
#  'YTbAAhqvJOw',
#  'tplJ3GvhNAI',
#  '0K5I-DCV2tU',
#  'P6I-bB5KXyU',
#  'U6YuvIb0VKY',
#  'YN1rgbQDkg0',
#  'RfjtfLmbF-g',
#  'XUXYjjeH82c',
#  'NCtJN3_Bxb8',
#  'a-ix_PyYc4c',
#  'EdDlq6vO_Nw',
#  '5ZBUxHFV_h4',
#  '_vCmjAinlZY',
#  'UdCmZCvBeZQ',
#  'U45b-UisiGs',
#  'jDSKfWB1dEM',
#  'jdFFmCrhXF8',
#  'C1YfOTAD42M',
#  '3-hEHTPfUWY',
#  'wVKp-7mDG1U',
#  'f5OIH26JsOA',
#  'QxP-iNev_LQ',
#  'fir8mUMK7r4',
#  'cXzGNcmt7rE',
#  '4b_Zx7rzwSE',
#  'g_hWakICku0',
#  'VViSs8eSIv8',
#  'z1swYb5CH9U',
#  'ytfB-mrGnFs',
#  'UIbBVlD80TA',
#  'mZc0Yomn9uA',
#  'OwZ2KzbTZIw',
#  'MdSPdunnm_U',
#  'FwxSm6EdJUU',
#  'ZQ-IPBs1NNQ',
#  'hoTHuI4KAOE',
#  'MQ1x3hdOU1o',
#  '7Y2yMp4V_Ns',
#  'Ia91E2OdZus',
#  'Q-raBWqkXL8',
#  'jPh8HjGdRrE',
#  'Y0EZ9wLygRc',
#  'nzF4dOk1Q5s',
#  '-y8-6kaX-y0',
#  '3uYsdRIGG84',
#  'VxyCCEx_g5c',
#  'eHn_U-S1CPE',
#  'ZUEaQwjOWmA',
#  'k2XBQPtM92I',
#  'VyjXPI40rHg',
#  'JTQlTaY30NA',
#  '603OQEdWFpk',
#  '-fQC_BsWbxc',
#  'eGzOqNde3SU',
#  '3ywADcxe6JM',
#  'X8xvQ3ZaoIA',
#  '_exnXGhMZp8',
#  'IXeMTgzQGMY',
#  '1AkCPtC0sGM',
#  '3XWG33ksRu0',
#  'F8KkaWkzEvg',
#  'gbtvJkXGDYg',
#  'ZLrtQLoYQe4',
#  'eOq8_0ImziU',
#  '2eLcYlbiq0s',
#  'JDjZB9e9608',
#  'C1MxXpjqeME',
#  '3xBRNVi-0lo',
#  'MTnVcdVQBog',
#  '-F2Yr4XGK68',
#  '-fVbVM8RQNg',
#  'OI-GzlzbsF4',
#  'eZkA_SgswtI',
#  '_dhh5vdWnRs',
#  'lxLCP3-YvxQ',
#  'MzvePwbBdXk',
#  'ii1dyR93oSc',
#  'OpGaT5ovti4',
#  'gcsMNPkndEk',
#  'vbzQmjV6SME',
#  'l0JWNn6axXk',
#  'E4B2UaPVd_o',
#  'PlxRYBbezXs',
#  'EN1pIM1-3bQ',
#  'Km2kVDCLwJE',
#  '22EHJ7Q0BFM',
#  'lR0VeyVn7mI',
#  'h3EYs4UsMJM',
#  'ZrX2C7c5UQY',
#  'zm6KalS97sA',
#  'yhBnuESYJdY',
#  'iali793ichk',
#  'bAX7K0LEsiM',
#  'f1EjtOuk2SQ',
#  'VnqYneDyYHY',
#  '1mS99Gmw1sI',
#  'XFQlwNCACms',
#  'PaAhbeTa5oQ',
#  'J_-NIWAtc8U',
#  'ecWcjl6Gyog',
#  'tCBdnxV7iaE',
#  'IEUK8DutlnU',
#  'Y2MUU061geE',
#  'FGPjCIp72Yk',
#  'KX24mLDwM0Q',
#  'nTsuWaT67Nc',
#  'VQeySLmSMhc',
#  'lJ7fNX7YV2w',
#  '4w5DWVK8R1g',
#  'ldLKRYJ6WXQ',
#  '_3HxSQry9K8',
#  'vGjZXL3GMys',
#  'mfo807-ApWI',
#  'BH3gGIQxF3o',
#  '2cd7MnpmwfQ',
#  'NNHG7eTIJoE',
#  'IEnMpQjPpfA',
#  'jTddky8cpsM',
#  'qtkcJ2Ub7sI',
#  '21lm9yJkQwQ',
#  'wue5q8Nb3Z4',
#  'b5BUj2cyWTg',
#  'UKcWuL-knMA',
#  'GaJ_iSEaYPM',
#  'FTfx0dq5RB4',
#  'La2dVvTBgE0',
#  'm4Vo4TuU5S4',
#  'CVzEViuwRVM',
#  'yFtb20O70P8',
#  'Zak0XAGVm4c',
#  '_BgG-EJAbiU',
#  'TAaiDILVEuc',
#  '_3qBjSJmepg',
#  '5zuXeN1ReSw',
#  'XFBfyefnZbg',
#  'U6-sKATNfDU',
#  'FFUfdffWYkU',
#  'FEAxC4nvASA',
#  'CF0asz8xIvo',
#  '4HqA-fBBL20',
#  'r0NCNlXiTyM',
#  'h-_GUlto1HI',
#  'PYL1WmETg8s',
#  'h30WTN_zxnc',
#  't-jVoCOZ9dg',
#  'F5qRVLsHIMU',
#  'GQfiCP7l6S8',
#  'z07Ttvegm6A',
#  'Wf8lPm8qJ-8',
#  'RtFFe8G89_U',
#  'iOu-8TcacDk',
#  'lXKMdPyUHQY',
#  'QN1HUaPO8yw',
#  'yS8ZAp1geNM',
#  'nlTysI5dtSk',
#  'L_fK044wEH4',
#  'RMXR3snavxc',
#  'O6SSGruCnmU',
#  'z-ODHa-HYFU',
#  'u-WNbsrqQpo',
#  'RJAy8PmQdv4',
#  'oyXqyvfejB8',
#  'U0lSg6eefN8',
#  'K92x1YUwTrY',
#  'TzaDPqOVmMc',
#  'btpVTpOUaoU',
#  'V9Ic5gDxTIM',
#  's9DefwiBsAg',
#  'Nn419HhsdvU',
#  'i9MgCZvMdNU',
#  'e9K-5jp-kfs',
#  'R8AdF7GGZ9E',
#  'lvSnH0wgZIA',
#  'zmuj--CAS0U',
#  'WvI4C1IlceE',
#  'c3s-CFhnags',
#  '_ju04aiuxKI',
#  '8EijKtphnKE',
#  '4EsrLp94LAU',
#  '_nMxRsiNVc8',
#  'EE_DWQwDSsk',
#  'LuGNlG9FNa8',
#  'SflJ0wsu22o',
#  'tvMRwvhAA2g',
#  'YEkqKQHHMT0',
#  'p4qfwfZblRI',
#  'uBL9W5pNaoU',
#  'h5LFWz2N9r4',
#  '3ImUHF6YUK8',
#  '3Ex37BZ9LhQ',
#  'jV68yMnH01o',
#  'hodSlGQKvUY',
#  'kAl_gkOy9x0',
#  '5n0RAlECWc4',
#  'RBiyPWopr6I',
#  'tzpL51VpGmQ',
#  'UoyAFA8em_g',
#  '6OTf3TUIKGQ',
#  'sZJd4epkDu4',
#  'LZ2ei13lkIw',
#  '7T9m-fwcB4I',
#  'TvmVxN8TmVc',
#  'lrEu_SPosOY',
#  'ovgqr3fQ6wg',
#  'P6EJ_NhMd-M',
#  'rmgyv6-P04o',
#  'UdMowkti0T4',
#  'YOISPDFUJiU',
#  'pMLOm83wKi0',
#  'GbbT1p32FUk',
#  'Agy7MFlMC6k',
#  'eXE61hHaUVc',
#  'aVuJRYKfYgg',
#  'vxx4dfTiRVU',
#  'ev0RQOSkp8c',
#  'jha8DYrhUYE',
#  'YWgK-OeyLO8',
#  'DjtE-3M4sIk',
#  '4BFVEMIvucw',
#  'lk2k-etMMjw',
#  'wEFy7NNiq00',
#  '_wv_kPWcn18',
#  'tBP22mdSwgg',
#  '--WdaIhN5sM',
#  'TTfal-OPw2M',
#  'OWnkOGZSZQ8',
#  'ejT_gjDh07A',
#  'eTYqwLm60Os',
#  'eL-zUtipPtk',
#  'P2-yQW-k4uo',
#  'TxdogdlLBGs',
#  'b-r-p9fShOQ',
#  'rqVniDOVEOc',
#  'AfONuGpdDLA',
#  'iMqCsEp2J1g',
#  'xnZK8uo4RYE',
#  'zPj0F7DVFWY',
#  'rVsv1uKjhQU',
#  '9Dd97mts6Ew',
#  'yE1qi1_EaIA',
#  '96ILBjEwqGc',
#  'kbNsLFmL9Io',
#  'MjklSdr4Esg',
#  'wnVyRFuGjiA',
#  'Q8OTSdAiTQM',
#  'OzQmbyaidbY',
#  '1kAkF6lnjj8',
#  'Ie7chZTr_6k',
#  '5wi8VPLGIrM',
#  'jvkU36R0Nrk',
#  'wRVp1h7-lK0',
#  'KLSG4wFOUqk',
#  'Jqto0xxc-Lg',
#  'jkybjYmwQYE',
#  'xOJ6tbcNkqU',
#  'LCEMMgQjerA',
#  'FuNbUXZBYyw',
#  'IziUTp_zQ40',
#  'augsekIFmzw',
#  'mN0JNAZyppo',
#  'lWXpal85nWU',
#  'N3q7A1-FevU',
#  'xtSCbyMUIEk',
#  'PR-Zm9JlTdM',
#  'MNwQkCd1uD4',
#  'xPRK0b3BMJM',
#  'UXPo_ePuPsY',
#  'VsFvvdeKi5E',
#  'c6cNvIF_laA',
#  '0Ph2NCkEGpY',
#  'wtghihIr1XQ',
#  '4ypTy72o_tM',
#  'q5xbAq1DvEc',
#  'XHRCClXY3aA',
#  'PdlSVHkbOP0',
#  'qdzJFzPSCfA',
#  'SqT-ew8rwPI',
#  'a-1PjnGA2-I',
#  'QIijRkaE_q8',
#  'Z-rJ7F1CUmQ',
#  '5j5zCGz_N0w',
#  'MZTB2hz6ASg',
#  '_OjSf8F2gJo',
#  'ICE7f9q5GNs',
#  '1g_6zwLEKN4',
#  'lVzzsHeU_gE',
#  '8bglQlBonD4',
#  'n6XCy29XCsY',
#  '-0dtv71ZdFM',
#  'ppD0t48cpQc',
#  'KgM6wV6dmsU',
#  '7cwEFN6AX_k',
#  'nzeCqKf0PVI',
#  'iWAZaewiGc0',
#  '43JkN4Slj3Q',
#  'FIc0fJLcG6w',
#  '63p-16sVISc',
#  'RtoUS7EHQXw',
#  'IFM_U9jjTFY',
#  'vqEq19nCtw8',
#  'heKTT9sF5tg',
#  'xS-PtZcbsbI',
#  's-INp0FxjXA',
#  'N9tJBhAO00k',
#  '_ZLChWQzbkw',
#  'B83wCLBamKk',
#  'opaok2uGpbI',
#  'tfPaRryXJMc',
#  'JzQOlFpH6WQ',
#  'GOd-g980mUg',
#  'ocl5ZPwCdm4',
#  'y0-dYWeWEP8',
#  'li63hkmwUVA',
#  '1rYGCP52fG8',
#  '3Qgtz3lpvxA',
#  '-jYMh89zZxA',
#  'eGpjIHSNZJQ',
#  'N3CSUmX4bFk',
#  'O0BxBXzVCKw',
#  'ot9tYRH8V0w',
#  'HzipLfgsJ7A',
#  'dFl1IHagWkA',
#  '6gVeg0qk-mM',
#  'Blo0BZ10eZU',
#  'liCzWftYzjU',
#  '6k9UAeCqySk',
#  'f-Mqh04cXco',
#  '9IQXG9tB-DU',
#  'yEK3gXScnxQ',
#  '_5j8QXzRXAk',
#  'DxLhzN4__pw',
#  'j1i8VXxvlII',
#  '5dtN0ApAGZs',
#  'izGLdgs4u9k',
#  'TubMjWlPNKI',
#  'H_iLiB7XKVg',
#  'k9A-8lKy5lc',
#  'cZj1JTo4FN4',
#  'BxnGKsuVz1E',
#  'r68-ohSRNJI',
#  'kJQOlqXrD0Y',
#  'W5VoHojCaxw',
#  'NHGPDmpnVOo',
#  'bv_DdZT1q3I',
#  'W1efYq56WOA',
#  'r5jbQc-36Rg',
#  '0n12R-yn__k',
#  'qKsXhtkdUi0',
#  '8bFXs1zkIEM',
#  'qicZnqch0ZA',
#  '3bb_nbP5Fm0',
#  '8I0Uy-6ZSZs',
#  'VbK_86QwooY',
#  'VZGw-YqV_rg',
#  'biSn1BvKZM0',
#  '_Z08Te3u_rQ',
#  'llcKsSDgZNU',
#  'rYS3fXf1GdY',
#  'PBxRfR-tEHE',
#  'zv6qUwOwquE',
#  '6GbLR7NMNcA',
#  'scljnnnPqyI',
#  '7l5J70JEdFc',
#  'ixbUzhlyjZw',
#  '6b_Ml18so58',
#  'e_9o5Ue-8TM',
#  '5coqGlNCyYc',
#  'Iu9viG4LOqU',
#  'xiro75ATNvU',
#  'VK8Ib9TMRhw',
#  'DifsSqIpo7A',
#  '1mZkxb94QXA',
#  'wSJBRtNCe7o',
#  'IKvhCIi3PTE',
#  'Pp93iZrl2S0',
#  'HPWZzwIkM70',
#  'YwM4TvduCFI',
#  'W1sCW1EbvvY',
#  '8n92SaJ_NkY',
#  '7wo2OuyzgMk',
#  'p9Yg5VK588k',
#  'DMjPReroT80',
#  '2lcsKTonyL4',
#  'SIE0ncMhPTw',
#  'SpbE9aK1C-Q',
#  'SJnvbS5Nzlk',
#  'GcEDsl-5Jp0',
#  'lsk2FrbkWoQ',
#  '6m9r3XoqgP4',
#  '39_0ew7dlrY',
#  'myT7KouXoH0',
#  '8oEMEZjT8js',
#  'qpUTR8zlG20',
#  'DOGhx0QdiWw',
#  'L7mQ9VGnL6Q',
#  'NACQcgzPYgY',
#  's6oRiYn1WmA',
#  'TWsxiYqvyQU',
#  '65wlgauMGfk',
#  'OurOsJU_qLY',
#  'WqQ3rGKtDVQ',
#  '0GSlHfjTYJY',
#  'ymyDC_0mEzk',
#  '_2pA3gIXlZ4',
#  'NAA7fPC8v7w',
#  'eBoJXf75Oms',
#  'a1OPFxYj1Qk',
#  'JCFzCuvWQRQ',
#  'qQlNHbrF_nk',
#  'zJikDCtyJgE',
#  'b_sq3qgvJIk',
#  'm8JPSeCsrtM',
#  'tpirB1Xx22A',
#  'lq2CPN7go3c',
#  'Spi5j8oOtfY',
#  's-tVrOZv4-8',
#  '426AgwpAfpM',
#  'OZUp5wKoxAM',
#  'Pvvr9vumsD8',
#  '7tAxKnLAiJ0',
#  'I1VymXVQJBk',
#  'R1ncIEKgFYA',
#  'sYvdwVLm9mg',
#  'eR0ozljmdTU',
#  '1ZrKvdtHT-I',
#  'YOCc4qAFF_A',
#  'qGBv-CZQK6w',
#  'NN6mFYwT6nM',
#  '4XsfwD1ZwlU',
#  'dWPMo5wxSsE',
#  'yHqNdUHGN4A',
#  '3VwURrUBHY4',
#  'mLkKgV-254s',
#  'KvTCjkD8vBg',
#  'nyaFbb1Yroc',
#  'iMTHLwP2igE',
#  'XzC0VrA08Ps',
#  'DVaLQlrbBNs',
#  'aU6EMGtywd0',
#  'ocWC3Ido7j0',
#  'q1IqeqpqEWY',
#  'asv4YN5DL1w',
#  'kFCzkwzGVjc',
#  'YLEWmTkASUc',
#  'idO4Mr247Ew',
#  'LQOU4WK0mCc',
#  'FpBjM7RcV1U',
#  'KqCrsj1nF48',
#  'hn5z3kCDYyI',
#  'J5oIo2X3zJQ',
#  'RZuTPJFj9aI',
#  '9ym9_XH2ass',
#  'fKicBBEwvbQ',
#  'IXVM8YxjRIQ',
#  'P-k_qtZRhAs',
#  'fYVeE6v407U',
#  'v8uq7P2cjb8',
#  'PzA0RVHfZ6Y',
#  'hBhwwND0dbI',
#  'DnTyr7Z_Y1U',
#  'U4iGES-IK3M',
#  'yrJsCGqn8es',
#  'RrBwF-7Hsrw',
#  'iWwO0esLaPY',
#  'IrbYy63Fx0c',
#  'dwPQHEGaEK0',
#  'Ylt4bZqJMOI',
#  '2Z8Ugr-U4NA',
#  '1qyz5mnErRs',
#  '7m6xvOD7z2U',
#  'Q6vxEmZsyU8',
#  'uw-eyglcJJk',
#  '9iD6DeUpE7U',
#  '2Kyzp76NggE',
#  'nWW_TjMVUzQ',
#  'mIXpZ233wII',
#  'wkMxUQWVRQ8',
#  'J1uj7ka7CMU',
#  'oWJB84MKky4',
#  '4v2LSqrG3gc',
#  'iKjLL_pFZOs',
#  'gpUeawxtefs',
#  'VsJ598wZ21g',
#  '_SfsUwWPcNM',
#  '_YGW4zR6VKg',
#  'N0hVcnPm6nY',
#  'H4e4oUOwm88',
#  'VmKeZETjrKQ',
#  'ZGawaWQejiE',
#  'f2lKxjKcCZo',
#  'gPp5hYTrwSg',
#  '1uHMG5PLuxs',
#  'FKM2kA8QPHs',
#  'g71mdHd2cNw',
#  'MvD0H7mMjbE',
#  'n2Y9pqHiFSw',
#  'q-BMApxi-mg',
#  'iyd_nljAGOM',
#  'OHwNehtOaFo',
#  'M3bC1EYcT74',
#  'r1gybUxuZd0',
#  'kyzdUSI7MMI',
#  'sLyT8tWDz6M',
#  '5Hv3HALM8X4',
#  'lM900_e-C-Y',
#  'ARnIeMIsVik',
#  'EugpUt1Y-LU',
#  'Hc5tEs9xQk0',
#  'W3HCR52GeY0',
#  'exWVFfpmmJA',
#  '2HbtYeYjRms',
#  'Rn818upa_M8',
#  'MnLGKvCp7yY',
#  'qnNdm21qx5I',
#  'TkUqrwKTgPU',
#  '2tWYfPQNW4U',
#  '6bBjmHxlOp8',
#  'CtofRPOTmA4',
#  'QV4ZF0gLtGA',
#  'Ngc3r7ROepM',
#  'bcrv3x3By2s',
#  'uPmnB0JqpFY',
#  'JFgOyp51SAc',
#  'btc08n7Qalk',
#  'k1rZ8zKojLA',
#  's0bjazaOYmA',
#  '9ie2mWXKYog',
#  'kLS8abVSEYw',
#  'M4PPzeofRDU',
#  'hZif8j4947E',
#  'SrtE6QfFfho',
#  'kQk-l8xcoAw',
#  'tI8gVRHvK6A',
#  '40SE-HhKFc4',
#  'ApcGJKYihwQ',
#  'RrvvXxtLSvA',
#  '5dIsVoLtk0o',
#  'L5L_TYdkLQs',
#  'ZJs7oIKO6cA',
#  'M8PtoPcPzbQ',
#  'u7oVP3hftaM',
#  'dcmF1kGgTzI',
#  'RwURkOuLiqA',
#  'wp66x3s4y6o',
#  'hENCMBL6sJo',
#  'ugOfugwvdeY',
#  'nvLgOAJM6g8',
#  'laYNkVP-2tg',
#  'S0OkioSOclA',
#  'k2gB8QaKO50',
#  '3Tewj90EMAo',
#  'GFcwDR5muLc',
#  'xhAyejuyyxM',
#  'S_KPNmJkRp4',
#  'A1PwF6C_KHk',
#  'q_Fq7thYyps',
#  '5glt7nDxkyI',
#  'kaOwuKF52F8',
#  'vE-LBiAsK-k',
#  'enFZbLKg9Lc',
#  '2PY2MPV3MPw',
#  '5TosClh7VZM',
#  'cl6H9Yecl34',
#  'PE_6-n6lFFc',
#  'tnM-toQGVDw',
#  'FEwXsFTiF_8',
#  'GXlTMpMVvsc',
#  'faMyNjstHzE',
#  'jQ9MDvOTdVI',
#  '6i47dzlX8-o',
#  'rS8TfQ9QoAE',
#  '13G5ldM2ERo',
#  '5t_5I7N3bCA',
#  'dSry9DtFp0A',
#  'syrWcKmhzFg',
#  'CA09GTar-rQ',
#  'Kxbs858Wr28',
#  'j0rg14NUbt8',
#  '_RB-5R2z1tE',
#  'eTxzKdXzd3g',
#  'XEfjpTMlWe4',
#  'tQj1j-MmE0Q',
#  '6o9St2__-tk',
#  'SCMFJRxct9c',
#  'h6ArOtPEihE',
#  '_XjNPkSCYgk',
#  'QGx9Pq4OaPw',
#  '8gUrxnvTR48',
#  'BLp6r9PAhyk',
#  'Sp3Q1VvL0Vg',
#  '_Sapa6UU8p0',
#  'pfFCOtCNiZY',
#  'jhDDMO_iM_w',
#  'KvmShTM2o6I',
#  'CB2uTRNNn20',
#  'vf_ABG4SdG8',
#  'nz-7skV82LU',
#  'XD9LjUAHeQI',
#  'G-qp4j75bBA',
#  '6e14Mh2WyD8',
#  'JBBDbxZey5M',
#  'LXXs3bO6vRk',
#  'gbfUWljZtBM',
#  'qMtCdGGWHJ8',
#  'ZEfuK1GEO3I',
#  'xgZh2MWElzs',
#  'SfTTyNGhkuA',
#  'Pp7YpqGceR0',
#  'hs1n11lNPP0',
#  'y0bFkvTw-h8',
#  'WLLKXHC4u7g',
#  'OsQNUzymwfs',
#  'p8WLKqnlP_Q',
#  'iKwTvXlOxiw',
#  'Wx2KwLEscsE',
#  'VO8Sz0kXWWY',
#  'C16krdqeu_g',
#  '6vjbZOkvKgY',
#  'TpnQsRf2G34',
#  '8sPG9HmFv9k',
#  's1jCYs42eFg',
#  'Xk09ty0aHGE',
#  'rd8CUyApJzk',
#  'gK7WsN3JtXw',
#  'bxbRdwC3CJA',
#  ...]

# %% [markdown]
# Writing the function to fetch the video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part= "snippet, statistics",
            id= ','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response['items']:
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               Views = video['statistics']['viewCount'],
                               Likes = video['statistics']['likeCount'],
                               Comments = video['statistics']['commentCount'])
            all_video_stats.append(video_stats)
            
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
video_details
# Out:
# [{'Title': 'I Played GTA 5 on Android Smartphone ! *High Settings*',
#   'Published_date': '2024-06-26T18:28:26Z',
#   'Views': '823747',
#   'Likes': '51572',
#   'Comments': '2446'},
#  {'Title': 'This Smartphone is Confusing ! *OnePlus Nord CE 4 Lite*',
#   'Published_date': '2024-06-24T13:51:41Z',
#   'Views': '335426',
#   'Likes': '14002',
#   'Comments': '757'},
#  {'Title': '10 Best Upcoming Smartphones of July 2024 !',
#   'Published_date': '2024-06-24T08:52:51Z',
#   'Views': '666678',
#   'Likes': '24535',
#   'Comments': '1025'},
#  {'Title': 'I Tried this Smart Health Ring !',
#   'Published_date': '2024-06-23T07:13:34Z',
#   'Views': '380917',
#   'Likes': '14101',
#   'Comments': '477'},
#  {'Title': 'Best Deals on Samsung Devices for Students ! *Back to Campus Sale*',
#   'Published_date': '2024-06-22T11:12:55Z',
#   'Views': '305040',
#   'Likes': '11539',
#   'Comments': '470'},
#  {'Title': 'Realme GT 6 Unboxing - Majeedar BGMI Features !',
#   'Published_date': '2024-06-20T09:34:05Z',
#   'Views': '380434',
#   'Likes': '17696',
#   'Comments': '831'},
#  {'Title': 'The Flagship Phone that No One Expected ! *Motorola Edge 50 Ultra*',
#   'Published_date': '2024-06-18T12:42:02Z',
#   'Views': '690055',
#   'Likes': '22320',
#   'Comments': '1094'},
#  {'Title': '5 Best Smartphones To Buy Under ₹25,000 !',
#   'Published_date': '2024-06-15T16:08:46Z',
#   'Views': '1154954',
#   'Likes': '40019',
#   'Comments': '2290'},
#  {'Title': 'Xiaomi 14 CIVI Unboxing - Flagship Killer Camera !',
#   'Published_date': '2024-06-12T15:22:59Z',
#   'Views': '614715',
#   'Likes': '21737',
#   'Comments': '943'},
#  {'Title': 'Apple Launched NEW AI Features ! *Apple Intelligence*',
#   'Published_date': '2024-06-11T16:04:21Z',
#   'Views': '2238565',
#   'Likes': '55309',
#   'Comments': '1823'},
#  {'Title': 'Tecno Camon 30 Premier Review - Fully Changed !',
#   'Published_date': '2024-06-10T14:51:16Z',
#   'Views': '464208',
#   'Likes': '18292',
#   'Comments': '722'},
#  {'Title': "7 World Cup Tech You Didn't Know !",
#   'Published_date': '2024-06-08T17:06:57Z',
#   'Views': '1873864',
#   'Likes': '71247',
#   'Comments': '1211'},
#  {'Title': 'vivo X Fold3 Pro Unboxing - Perfect Fold Ever ?',
#   'Published_date': '2024-06-06T11:41:02Z',
#   'Views': '663044',
#   'Likes': '22306',
#   'Comments': '908'},
#  {'Title': "World's Best Smartphone Camera, Disappointed Me !",
#   'Published_date': '2024-06-05T17:48:57Z',
#   'Views': '790951',
#   'Likes': '29239',
#   'Comments': '983'},
#  {'Title': 'Beware of These Apps on Your Smartphone !',
#   'Published_date': '2024-06-03T17:33:09Z',
#   'Views': '1342867',
#   'Likes': '73345',
#   'Comments': '3312'},
#  {'Title': 'I Bought Mini Tesla Cybertruck ! *Official*',
#   'Published_date': '2024-06-01T12:38:57Z',
#   'Views': '1744912',
#   'Likes': '45350',
#   'Comments': '1058'},
#  {'Title': '10 Best Upcoming Smartphones of June 2024 !',
#   'Published_date': '2024-05-29T13:54:07Z',
#   'Views': '743341',
#   'Likes': '26360',
#   'Comments': '1066'},
#  {'Title': 'Samsung Galaxy F55 Unboxing - New Design, New Price !',
#   'Published_date': '2024-05-27T16:30:43Z',
#   'Views': '523245',
#   'Likes': '19296',
#   'Comments': '734'},
#  {'Title': 'This Gaming Laptop is Value for Money ! *Infinix GT Book*',
#   'Published_date': '2024-05-25T14:53:08Z',
#   'Views': '558434',
#   'Likes': '22447',
#   'Comments': '1220'},
#  {'Title': 'POCO F6 Unboxing - Flagship Killer Performance @ ₹25,999* !',
#   'Published_date': '2024-05-23T12:35:06Z',
#   'Views': '438869',
#   'Likes': '17341',
#   'Comments': '1562'},
#  {'Title': 'Realme GT 6T Unboxing & Quick Look ! *Best Performance Under ₹25K ?*',
#   'Published_date': '2024-05-22T08:00:56Z',
#   'Views': '580218',
#   'Likes': '20405',
#   'Comments': '931'},
#  {'Title': 'This ₹22,999 Gaming Phone has Majedaar Features! *Infinix GT 20 Pro*',
#   'Published_date': '2024-05-21T06:36:12Z',
#   'Views': '1409996',
#   'Likes': '55746',
#   'Comments': '1979'},
#  {'Title': 'This is My Last Video Here ! *Bye Bye Studio*',
#   'Published_date': '2024-05-20T17:46:51Z',
#   'Views': '567543',
#   'Likes': '30926',
#   'Comments': '1235'},
#  {'Title': 'Google Launched FREE AI Tools ! *Bye Bye Chat GPT*',
#   'Published_date': '2024-05-17T14:20:51Z',
#   'Views': '1142389',
#   'Likes': '40305',
#   'Comments': '1458'},
#  {'Title': 'Motorola Edge 50 Fusion Unboxing - Best Smartphone Under  ₹25K ?',
#   'Published_date': '2024-05-16T07:05:39Z',
#   'Views': '1641167',
#   'Likes': '44807',
#   'Comments': '2141'},
#  {'Title': '7 Majedaar Indian Election Tech !',
#   'Published_date': '2024-05-13T14:45:20Z',
#   'Views': '4028891',
#   'Likes': '98360',
#   'Comments': '6506'},
#  {'Title': 'Airtel Sent me a Special Box ! *Unlimited Entertainment*',
#   'Published_date': '2024-05-11T16:07:38Z',
#   'Views': '591916',
#   'Likes': '19293',
#   'Comments': '735'},
#  {'Title': 'Can This Smartphone Replace DSLR ? *OPPO Find X7 Ultra*',
#   'Published_date': '2024-05-09T09:30:29Z',
#   'Views': '434320',
#   'Likes': '17222',
#   'Comments': '570'},
#  {'Title': 'I Tested Majedaar Gadgets Under ₹100  !',
#   'Published_date': '2024-05-06T16:35:49Z',
#   'Views': '1759858',
#   'Likes': '62810',
#   'Comments': '1614'},
#  {'Title': 'Trying Xiaomi Car Features for First Time !',
#   'Published_date': '2024-05-03T11:47:04Z',
#   'Views': '2063002',
#   'Likes': '55993',
#   'Comments': '2008'},
#  {'Title': 'Samsung Galaxy S23 FE - New Price, New Galaxy AI Features ! *Flipkart BSD Sale*',
#   'Published_date': '2024-05-02T13:08:10Z',
#   'Views': '717609',
#   'Likes': '21763',
#   'Comments': '849'},
#  {'Title': 'POCO X6 Pro - New Price Changes Everything !',
#   'Published_date': '2024-04-30T08:08:12Z',
#   'Views': '828360',
#   'Likes': '34164',
#   'Comments': '2170'},
#  {'Title': 'This Gaming Laptop Can Customize Performance ! *Alienware M16 R2*',
#   'Published_date': '2024-04-28T17:43:22Z',
#   'Views': '670025',
#   'Likes': '25970',
#   'Comments': '823'},
#  {'Title': "What's in my Tech Bag ? 2024",
#   'Published_date': '2024-04-27T14:18:34Z',
#   'Views': '581645',
#   'Likes': '28379',
#   'Comments': '704'},
#  {'Title': '5 IPL Gadgets I Bought Online !',
#   'Published_date': '2024-04-25T14:04:25Z',
#   'Views': '1888899',
#   'Likes': '44041',
#   'Comments': '647'},
#  {'Title': "World's Best Smartphone Camera ! *OPPO Find X7 Ultra*",
#   'Published_date': '2024-04-23T14:17:03Z',
#   'Views': '897511',
#   'Likes': '30441',
#   'Comments': '1115'},
#  {'Title': 'Realme P1 Series Unboxing - Best Display Under ₹20,000 !',
#   'Published_date': '2024-04-21T15:46:05Z',
#   'Views': '622973',
#   'Likes': '22972',
#   'Comments': '1143'},
#  {'Title': 'I Made ₹5,000 iPhone in China ! *iPhone 6s*',
#   'Published_date': '2024-04-20T16:20:41Z',
#   'Views': '2042977',
#   'Likes': '68530',
#   'Comments': '2740'},
#  {'Title': '5 Best Smartphones Under ₹10,000 !',
#   'Published_date': '2024-04-18T13:32:04Z',
#   'Views': '1316179',
#   'Likes': '40257',
#   'Comments': '2163'},
#  {'Title': 'moto g64 5G Unboxing - All Round Budget Phone @ ₹13,999 !',
#   'Published_date': '2024-04-16T06:41:39Z',
#   'Views': '607617',
#   'Likes': '19921',
#   'Comments': '1182'},
#  {'Title': "10 Majedaar IPL Tech You Didn't Know !",
#   'Published_date': '2024-04-15T12:26:46Z',
#   'Views': '3143492',
#   'Likes': '85463',
#   'Comments': '1391'},
#  {'Title': "World's Biggest Electric Car ! *Hummer EV*",
#   'Published_date': '2024-04-13T13:37:33Z',
#   'Views': '835308',
#   'Likes': '28697',
#   'Comments': '579'},
#  {'Title': 'Infinix Note 40 Pro Unboxing ! *Majeedar Charging Features*',
#   'Published_date': '2024-04-12T06:39:34Z',
#   'Views': '1221553',
#   'Likes': '40559',
#   'Comments': '1739'},
#  {'Title': 'Lenovo Yoga Slim 7i Unboxing ! *Microsoft\xa0Copilot*',
#   'Published_date': '2024-04-10T13:24:34Z',
#   'Views': '274210',
#   'Likes': '11274',
#   'Comments': '654'},
#  {'Title': 'Samsung Galaxy M55 5G Unboxing - Good or Bad ?',
#   'Published_date': '2024-04-08T07:07:55Z',
#   'Views': '713365',
#   'Likes': '26998',
#   'Comments': '1212'},
#  {'Title': '15 Hidden WhatsApp Tricks !',
#   'Published_date': '2024-04-06T10:01:52Z',
#   'Views': '562578',
#   'Likes': '31566',
#   'Comments': '935'},
#  {'Title': 'Motorola Edge 50 Pro Unboxing  - 50MP AI Camera 📸 144Hz Curved Display 📱 @ ₹27,999 !',
#   'Published_date': '2024-04-03T07:31:37Z',
#   'Views': '1429773',
#   'Likes': '41567',
#   'Comments': '1947'},
#  {'Title': 'OnePlus Nord CE 4 Unboxing & Quick Look ! *Value for Money?*',
#   'Published_date': '2024-04-01T13:55:33Z',
#   'Views': '1362806',
#   'Likes': '49179',
#   'Comments': '1457'},
#  {'Title': 'I Tried Chotu Vlogging Camera ! *Canon PowerShot V10*',
#   'Published_date': '2024-03-31T05:22:25Z',
#   'Views': '471479',
#   'Likes': '17475',
#   'Comments': '786'},
#  {'Title': 'I Used Apple iPhone 1 in 2024 !',
#   'Published_date': '2024-03-28T10:41:32Z',
#   'Views': '1393686',
#   'Likes': '57050',
#   'Comments': '1385'},
#  {'Title': 'Watching RCB vs CSK in Chennai ! Virat Kohli',
#   'Published_date': '2024-03-23T14:51:58Z',
#   'Views': '419165',
#   'Likes': '19997',
#   'Comments': '784'},
#  {'Title': 'vivo T3 5G Unboxing 📸  50MP Anti-Flicker Camera !',
#   'Published_date': '2024-03-21T06:39:56Z',
#   'Views': '1424074',
#   'Likes': '52350',
#   'Comments': '1792'},
#  {'Title': 'Samsung Galaxy Book4 Pro Unboxing - Thin & Light Laptop !',
#   'Published_date': '2024-03-20T17:10:20Z',
#   'Views': '565032',
#   'Likes': '21704',
#   'Comments': '794'},
#  {'Title': 'TechBurner Answers WEIRD Questions ! *QnA*',
#   'Published_date': '2024-03-19T15:18:37Z',
#   'Views': '390380',
#   'Likes': '27117',
#   'Comments': '1130'},
#  {'Title': 'I Tried Shark Tank Products !',
#   'Published_date': '2024-03-17T15:36:54Z',
#   'Views': '2687243',
#   'Likes': '97902',
#   'Comments': '1246'},
#  {'Title': 'I Tried Ferrari First Electric Car ! *Ferrari 296 GTS*',
#   'Published_date': '2024-03-15T14:24:42Z',
#   'Views': '886975',
#   'Likes': '38033',
#   'Comments': '1073'},
#  {'Title': 'Samsung Galaxy A55 Unboxing - New Build, New Price !',
#   'Published_date': '2024-03-13T09:40:28Z',
#   'Views': '2922827',
#   'Likes': '78205',
#   'Comments': '3212'},
#  {'Title': 'We Launched Our Digital School ! *Brightso*',
#   'Published_date': '2024-03-10T15:30:08Z',
#   'Views': '936619',
#   'Likes': '61835',
#   'Comments': '2796'},
#  {'Title': 'My New Secret Startup ! *BrightSo Teaser*',
#   'Published_date': '2024-03-08T17:41:07Z',
#   'Views': '404525',
#   'Likes': '26564',
#   'Comments': '1070'},
#  {'Title': 'iQOO Z9 Unboxing ⚡ MediaTek Dimensity 7200 @ ₹17,999',
#   'Published_date': '2024-03-08T06:48:30Z',
#   'Views': '930960',
#   'Likes': '43119',
#   'Comments': '1612'},
#  {'Title': 'vivo V30 Pro Unboxing - DSLR like Camera @ ₹40,000 !',
#   'Published_date': '2024-03-07T14:28:55Z',
#   'Views': '1394873',
#   'Likes': '48782',
#   'Comments': '1416'},
#  {'Title': 'Nothing Phone 2a Unboxing ! *Best Phone Under ₹25K?*',
#   'Published_date': '2024-03-05T12:50:24Z',
#   'Views': '3849799',
#   'Likes': '149116',
#   'Comments': '4258'},
#  {'Title': 'Lava Blaze Curve 5G Unboxing - 📱120Hz Curved Amoled @₹17,999 !',
#   'Published_date': '2024-03-05T06:30:04Z',
#   'Views': '1015567',
#   'Likes': '37118',
#   'Comments': '1371'},
#  {'Title': 'Samsung Galaxy F15  - Value for Money @ ₹11,999 *5 Years Updates*',
#   'Published_date': '2024-03-04T08:27:37Z',
#   'Views': '752035',
#   'Likes': '30492',
#   'Comments': '1168'},
#  {'Title': 'How To Buy a Perfect Smartphone in 2024 !',
#   'Published_date': '2024-03-02T13:35:44Z',
#   'Views': '1544772',
#   'Likes': '76134',
#   'Comments': '2523'},
#  {'Title': 'OPPO F25 Pro 5G Unboxing - 32MP Selfie 📸 & MediaTek 7050 ⚡️',
#   'Published_date': '2024-02-29T06:30:17Z',
#   'Views': '959025',
#   'Likes': '30475',
#   'Comments': '1272'},
#  {'Title': 'I Tried Tesla Cybertruck !',
#   'Published_date': '2024-02-27T15:37:16Z',
#   'Views': '6457160',
#   'Likes': '195487',
#   'Comments': '4459'},
#  {'Title': 'Xiaomi 14 Unboxing - DSLR like Leica Camera !',
#   'Published_date': '2024-02-25T16:01:13Z',
#   'Views': '928823',
#   'Likes': '37794',
#   'Comments': '1599'},
#  {'Title': '5 Best Smartphones Under ₹40,000 !',
#   'Published_date': '2024-02-24T13:47:07Z',
#   'Views': '1491247',
#   'Likes': '48762',
#   'Comments': '2406'},
#  {'Title': 'I Bought ₹2,00,000 AI Robot Dog !',
#   'Published_date': '2024-02-22T16:58:27Z',
#   'Views': '2219497',
#   'Likes': '59752',
#   'Comments': '1757'},
#  {'Title': '35 Majedaar AI Tools You Should Try !',
#   'Published_date': '2024-02-20T13:36:09Z',
#   'Views': '1780585',
#   'Likes': '91078',
#   'Comments': '1709'},
#  {'Title': 'I Spent A Day in Apple Vision Pro !',
#   'Published_date': '2024-02-17T13:25:26Z',
#   'Views': '1596869',
#   'Likes': '51077',
#   'Comments': '1439'},
#  {'Title': 'OnePlus 12 In-Depth Camera Review !',
#   'Published_date': '2024-02-15T15:59:38Z',
#   'Views': '874181',
#   'Likes': '27205',
#   'Comments': '1153'},
#  {'Title': "This Smartwatch Can Run BGMI, But Don't Buy !",
#   'Published_date': '2024-02-13T14:29:30Z',
#   'Views': '2370295',
#   'Likes': '63584',
#   'Comments': '2215'},
#  {'Title': 'Worlds Biggest Smartphone Camera  ! *Nubia Z60 Ultra*',
#   'Published_date': '2024-02-11T12:50:19Z',
#   'Views': '1954310',
#   'Likes': '63426',
#   'Comments': '2262'},
#  {'Title': 'I Tried Apple Vision Pro ! *The Future is Here*',
#   'Published_date': '2024-02-09T12:03:36Z',
#   'Views': '4303199',
#   'Likes': '139912',
#   'Comments': '3350'},
#  {'Title': '30 Futuristic Gadgets that Can Change the World!',
#   'Published_date': '2024-02-07T14:01:34Z',
#   'Views': '864734',
#   'Likes': '30988',
#   'Comments': '811'},
#  {'Title': 'OnePlus 12R Unboxing & Quick Look - ⚡️Snapdragon 8 Gen 2 & 🔋 5,500mAh',
#   'Published_date': '2024-02-05T14:00:08Z',
#   'Views': '642031',
#   'Likes': '23886',
#   'Comments': '835'},
#  {'Title': 'This Gaming Phone has Majedaar Features !',
#   'Published_date': '2024-02-03T13:39:58Z',
#   'Views': '1195011',
#   'Likes': '51541',
#   'Comments': '1786'},
#  {'Title': 'The Ultimate Smartphone OS Comparison !',
#   'Published_date': '2024-02-01T17:16:03Z',
#   'Views': '1615272',
#   'Likes': '66033',
#   'Comments': '3671'},
#  {'Title': 'Realme 12 Pro 5G Unboxing - Snapdragon 6 Gen 1 ⚡️ & 50MP Camera 📷',
#   'Published_date': '2024-01-30T05:30:10Z',
#   'Views': '1330279',
#   'Likes': '43821',
#   'Comments': '1248'},
#  {'Title': '5 Best Smartphones Under ₹25,000 !',
#   'Published_date': '2024-01-27T15:28:23Z',
#   'Views': '3388309',
#   'Likes': '119222',
#   'Comments': '4749'},
#  {'Title': 'Samsung Galaxy S24 & S24+ Unboxing - AI Magic 📷 & Exynos 2400 ⚡️',
#   'Published_date': '2024-01-25T11:54:36Z',
#   'Views': '888294',
#   'Likes': '31803',
#   'Comments': '890'},
#  {'Title': 'I Bought ₹3 Lakhs AI Electric Bedsheet !',
#   'Published_date': '2024-01-24T17:02:22Z',
#   'Views': '1062649',
#   'Likes': '42810',
#   'Comments': '1442'},
#  {'Title': 'Samsung Galaxy S24 Ultra Unboxing - The Ultimate AI Phone !',
#   'Published_date': '2024-01-22T12:47:20Z',
#   'Views': '3724005',
#   'Likes': '117834',
#   'Comments': '3569'},
#  {'Title': "Don't Buy These Made in India Smartphones !",
#   'Published_date': '2024-01-21T16:31:23Z',
#   'Views': '2130961',
#   'Likes': '94551',
#   'Comments': '2971'},
#  {'Title': 'I Bought ₹40,000 AI Dancing Robots !',
#   'Published_date': '2024-01-19T14:11:25Z',
#   'Views': '2045317',
#   'Likes': '31617',
#   'Comments': '969'},
#  {'Title': 'All New Samsung S24 Series is Here - Next Level AI !',
#   'Published_date': '2024-01-17T18:04:26Z',
#   'Views': '3005328',
#   'Likes': '105203',
#   'Comments': '2595'},
#  {'Title': 'OnePlus Open 30 Days Long Term Review !',
#   'Published_date': '2024-01-15T13:03:37Z',
#   'Views': '326030',
#   'Likes': '13101',
#   'Comments': '432'},
#  {'Title': 'POCO X6 Pro Unboxing and Quick Look - 120Hz📱 & Dimensity 8300 Ultra 🎮 @ ₹24,999 !',
#   'Published_date': '2024-01-12T05:00:19Z',
#   'Views': '829578',
#   'Likes': '37811',
#   'Comments': '2528'},
#  {'Title': 'moto G34 5G Unboxing and Quick Look - 120Hz📱 & 50MP 📷  @ ₹9,999 !',
#   'Published_date': '2024-01-09T06:30:14Z',
#   'Views': '1568337',
#   'Likes': '43699',
#   'Comments': '1344'},
#  {'Title': 'ROG Phone 8 Pro Unboxing and Quick Look - 165Hz📱 & Snapdragon 8 Gen 3 🎮',
#   'Published_date': '2024-01-09T03:58:18Z',
#   'Views': '2378151',
#   'Likes': '83794',
#   'Comments': '3082'},
#  {'Title': 'I Made GTA in Real Life !',
#   'Published_date': '2024-01-07T07:12:50Z',
#   'Views': '981550',
#   'Likes': '65065',
#   'Comments': '2462'},
#  {'Title': 'Redmi Note 13 Pro Plus Unboxing and Quick Look - 200MP 📷 & 120W🔋 !',
#   'Published_date': '2024-01-04T15:06:17Z',
#   'Views': '2086123',
#   'Likes': '70213',
#   'Comments': '2641'},
#  {'Title': 'Upcoming Tech of 2024 !',
#   'Published_date': '2024-01-03T09:34:17Z',
#   'Views': '688585',
#   'Likes': '30548',
#   'Comments': '938'},
#  {'Title': 'TechBurner 2023 Rewind🔥',
#   'Published_date': '2023-12-31T10:05:50Z',
#   'Views': '252900',
#   'Likes': '18824',
#   'Comments': '907'},
#  {'Title': 'The Truth of Tesla Robot | Can AI Destroy Humans ?',
#   'Published_date': '2023-12-30T07:43:59Z',
#   'Views': '750807',
#   'Likes': '30731',
#   'Comments': '872'},
#  {'Title': 'Realme GT5 Pro Unboxing -  Snapdragon 8 Gen 3 Under ₹40,000 !',
#   'Published_date': '2023-12-27T06:30:01Z',
#   'Views': '859378',
#   'Likes': '33124',
#   'Comments': '1641'},
#  {'Title': 'Lava Storm 5G Unboxing - Best Phone Under ₹15,000 ?',
#   'Published_date': '2023-12-26T06:30:24Z',
#   'Views': '497883',
#   'Likes': '24098',
#   'Comments': '1319'},
#  {'Title': "Don't Buy These Khatarnak Gadgets !",
#   'Published_date': '2023-12-23T12:54:39Z',
#   'Views': '909362',
#   'Likes': '43170',
#   'Comments': '1530'},
#  {'Title': 'We Clicked a 30,000 MegaPixel Photo with Smartphone !',
#   'Published_date': '2023-12-19T05:00:26Z',
#   'Views': '1885453',
#   'Likes': '90985',
#   'Comments': '2677'},
#  {'Title': 'Lenovo IdeaPad Slim 5i Unboxing & Review !',
#   'Published_date': '2023-12-17T05:00:18Z',
#   'Views': '1075266',
#   'Likes': '31191',
#   'Comments': '1624'},
#  {'Title': 'OnePlus 12 Unboxing - OnePlus is Back ?',
#   'Published_date': '2023-12-14T03:30:02Z',
#   'Views': '2094646',
#   'Likes': '67563',
#   'Comments': '2291'},
#  {'Title': 'iQOO 12 Unboxing & Quick Look - Flagship Killer ?',
#   'Published_date': '2023-12-12T12:30:07Z',
#   'Views': '1391992',
#   'Likes': '62042',
#   'Comments': '1607'},
#  {'Title': 'Vivo x100 Pro Unboxing - Can This Smartphone Replace DSLR?',
#   'Published_date': '2023-12-08T06:22:18Z',
#   'Views': '1330996',
#   'Likes': '54746',
#   'Comments': '2084'},
#  {'Title': 'GTA 6 Trailer Launched !*New Features & Breakdown*',
#   'Published_date': '2023-12-05T05:37:27Z',
#   'Views': '2423687',
#   'Likes': '129193',
#   'Comments': '2854'},
#  {'Title': '7 Majedaar AI Tools you Should Try !',
#   'Published_date': '2023-12-04T11:35:30Z',
#   'Views': '3278379',
#   'Likes': '138765',
#   'Comments': '2770'},
#  {'Title': 'I Spent ₹5 Lakhs to Live 100 Years !',
#   'Published_date': '2023-11-30T13:23:27Z',
#   'Views': '2518012',
#   'Likes': '121001',
#   'Comments': '3607'},
#  {'Title': 'This Smartwatch is Great Value for Money !',
#   'Published_date': '2023-11-28T13:04:32Z',
#   'Views': '1222065',
#   'Likes': '37315',
#   'Comments': '1122'},
#  {'Title': "World's Most Expensive Smartwatch ! *Louis Vuitton*",
#   'Published_date': '2023-11-24T13:34:29Z',
#   'Views': '3056892',
#   'Likes': '113677',
#   'Comments': '3028'},
#  {'Title': 'Beware Of These AI Scams !',
#   'Published_date': '2023-11-22T14:17:53Z',
#   'Views': '1767896',
#   'Likes': '87447',
#   'Comments': '2428'},
#  {'Title': '7 Useful Smartphone Gadgets !',
#   'Published_date': '2023-11-17T13:37:59Z',
#   'Views': '1250400',
#   'Likes': '57336',
#   'Comments': '1799'},
#  {'Title': 'Sony PlayStation VR2 Review | Majedaar 3D Gaming !',
#   'Published_date': '2023-11-14T13:43:36Z',
#   'Views': '802330',
#   'Likes': '34697',
#   'Comments': '906'},
#  {'Title': "World's Most Expensive Earphones ! *Louis Vuitton*",
#   'Published_date': '2023-11-11T02:53:53Z',
#   'Views': '3615581',
#   'Likes': '125314',
#   'Comments': '2700'},
#  {'Title': 'HP Chromebook Laptop Unboxing & Quick Look !',
#   'Published_date': '2023-11-07T11:58:24Z',
#   'Views': '1044691',
#   'Likes': '27068',
#   'Comments': '1035'},
#  {'Title': 'This is My Most Expensive Unboxing! *Overlays Factory*',
#   'Published_date': '2023-11-05T05:55:25Z',
#   'Views': '3309684',
#   'Likes': '140993',
#   'Comments': '4425'},
#  {'Title': 'Lava Blaze 2 5G Unboxing - Value for Money ?',
#   'Published_date': '2023-11-04T06:30:16Z',
#   'Views': '992005',
#   'Likes': '39855',
#   'Comments': '1117'},
#  {'Title': "We Made World's Biggest Jacket For Our Startup ! *Overlays*",
#   'Published_date': '2023-11-03T15:11:08Z',
#   'Views': '660646',
#   'Likes': '39923',
#   'Comments': '1504'},
#  {'Title': '7 Weird Gadgets I Bought Online !',
#   'Published_date': '2023-10-28T13:59:06Z',
#   'Views': '2627795',
#   'Likes': '82272',
#   'Comments': '1474'},
#  {'Title': 'Best Intel Evo Laptops to buy on Amazon & Flipkart!',
#   'Published_date': '2023-10-26T15:31:14Z',
#   'Views': '2369072',
#   'Likes': '102936',
#   'Comments': '907'},
#  {'Title': '25 Hidden iPhone Tricks !',
#   'Published_date': '2023-10-25T13:09:27Z',
#   'Views': '2298756',
#   'Likes': '89549',
#   'Comments': '2373'},
#  {'Title': 'OnePlus Open Unboxing - Best Folding Phone ?',
#   'Published_date': '2023-10-19T15:00:22Z',
#   'Views': '1337332',
#   'Likes': '41603',
#   'Comments': '1160'},
#  {'Title': 'Best Deals on OnePlus Nord Smartphones !',
#   'Published_date': '2023-10-18T08:17:20Z',
#   'Views': '316172',
#   'Likes': '13131',
#   'Comments': '532'},
#  {'Title': '7 Majedaar Indian Innovations !',
#   'Published_date': '2023-10-15T13:08:13Z',
#   'Views': '793430',
#   'Likes': '40254',
#   'Comments': '1113'},
#  {'Title': 'OPPO Find N3 Flip Unboxing - Flagship Flip Phone!',
#   'Published_date': '2023-10-12T14:27:38Z',
#   'Views': '553980',
#   'Likes': '20387',
#   'Comments': '687'},
#  {'Title': 'Google Pixel 8 & 8 Pro Unboxing ! *Software Magic*',
#   'Published_date': '2023-10-11T17:07:51Z',
#   'Views': '2182458',
#   'Likes': '71510',
#   'Comments': '1810'},
#  {'Title': 'Best Samsung Phones to buy on Amazon & Flipkart !',
#   'Published_date': '2023-10-09T18:29:55Z',
#   'Views': '783025',
#   'Likes': '26506',
#   'Comments': '1125'},
#  {'Title': 'OnePlus 11R Solar Red Unboxing | 18GB RAM Magic!',
#   'Published_date': '2023-10-08T10:10:10Z',
#   'Views': '1222545',
#   'Likes': '40776',
#   'Comments': '1479'},
#  {'Title': 'Samsung Galaxy S23 FE Unboxing & Quick Look !',
#   'Published_date': '2023-10-07T06:39:15Z',
#   'Views': '1365337',
#   'Likes': '44888',
#   'Comments': '1470'},
#  {'Title': 'Poco X5 Pro Long Term Review ! *Worth Buying?*',
#   'Published_date': '2023-10-06T14:40:59Z',
#   'Views': '833252',
#   'Likes': '33962',
#   'Comments': '2587'},
#  {'Title': 'Lava Agni 2 - New Price Changes Everything ! *Lava Report Card*',
#   'Published_date': '2023-10-06T07:47:53Z',
#   'Views': '599127',
#   'Likes': '26227',
#   'Comments': '1268'},
#  {'Title': 'Best Smartphones & Electronics Gadgets to buy on Flipkart Big Billion Days! 📦',
#   'Published_date': '2023-10-05T14:02:27Z',
#   'Views': '1569539',
#   'Likes': '59782',
#   'Comments': '1856'},
#  {'Title': 'Samsung Galaxy S23 FE First Look! New Changes 📱',
#   'Published_date': '2023-10-05T07:03:44Z',
#   'Views': '977527',
#   'Likes': '38700',
#   'Comments': '1307'},
#  {'Title': 'vivo V29 Pro Unboxing - DSLR like Camera Pics !',
#   'Published_date': '2023-10-04T11:35:37Z',
#   'Views': '2305887',
#   'Likes': '61311',
#   'Comments': '1582'},
#  {'Title': 'Best Smartphones to buy on Amazon Great Indian Festival !',
#   'Published_date': '2023-10-03T15:22:16Z',
#   'Views': '3879396',
#   'Likes': '75071',
#   'Comments': '2750'},
#  {'Title': 'Why everyone in India is buying iPhones now!',
#   'Published_date': '2023-10-02T16:05:55Z',
#   'Views': '3439873',
#   'Likes': '124708',
#   'Comments': '4257'},
#  {'Title': 'Tecno Phantom V Flip 5G Unboxing - Budget Friendly Flip Phone !',
#   'Published_date': '2023-10-01T08:32:34Z',
#   'Views': '969060',
#   'Likes': '34193',
#   'Comments': '999'},
#  {'Title': '1 Year Journey of our Special Project ! *layers.shop*',
#   'Published_date': '2023-09-30T15:17:40Z',
#   'Views': '792622',
#   'Likes': '53865',
#   'Comments': '2814'},
#  {'Title': 'This is a Mercedes Laptop *MSI Stealth 16*',
#   'Published_date': '2023-09-27T16:26:31Z',
#   'Views': '1034456',
#   'Likes': '44928',
#   'Comments': '1490'},
#  {'Title': "Nothing's CMF Watch & TWS - I am Confused !",
#   'Published_date': '2023-09-26T10:11:10Z',
#   'Views': '2436551',
#   'Likes': '71439',
#   'Comments': '1690'},
#  {'Title': "Samsung Galaxy Tab S9 Ultra 5G *World's Biggest Tablet* !",
#   'Published_date': '2023-09-24T03:00:15Z',
#   'Views': '1437963',
#   'Likes': '46193',
#   'Comments': '1402'},
#  {'Title': 'Apple iPhone 15 & 15 Plus Unboxing ! *Big Upgrade*',
#   'Published_date': '2023-09-21T04:46:23Z',
#   'Views': '3921857',
#   'Likes': '118413',
#   'Comments': '3189'},
#  {'Title': 'Apple iPhone 15 Pro & 15 Pro Max Unboxing ! *Big Upgrade*',
#   'Published_date': '2023-09-20T06:28:46Z',
#   'Views': '4286806',
#   'Likes': '150015',
#   'Comments': '3932'},
#  {'Title': 'I Tried ₹20,000 Invisible Drums !',
#   'Published_date': '2023-09-16T12:26:30Z',
#   'Views': '1611704',
#   'Likes': '54661',
#   'Comments': '1162'},
#  {'Title': 'Apple iPhone 15 Series First Look ! *Big Upgrade*',
#   'Published_date': '2023-09-13T05:08:37Z',
#   'Views': '5724290',
#   'Likes': '186402',
#   'Comments': '5250'},
#  {'Title': '₹10,000 iPhone vs ₹1,40,000 iPhone !',
#   'Published_date': '2023-09-10T08:57:36Z',
#   'Views': '3326557',
#   'Likes': '92018',
#   'Comments': '1624'},
#  {'Title': "I Visited Samsung's Futuristic City !",
#   'Published_date': '2023-09-09T03:00:01Z',
#   'Views': '2427463',
#   'Likes': '69353',
#   'Comments': '1022'},
#  {'Title': 'moto g54 5G - Unboxing & Review *New Budget King?*',
#   'Published_date': '2023-09-06T13:03:54Z',
#   'Views': '1691995',
#   'Likes': '58020',
#   'Comments': '1661'},
#  {'Title': 'I Tried Futuristic Luxury Car ! *BMW i7*',
#   'Published_date': '2023-09-05T17:25:36Z',
#   'Views': '4694921',
#   'Likes': '112181',
#   'Comments': '1462'},
#  {'Title': 'iQOO Z7 Pro Unboxing & Quick Look ! *Camera Magic*',
#   'Published_date': '2023-08-31T07:00:30Z',
#   'Views': '1125429',
#   'Likes': '45416',
#   'Comments': '1377'},
#  {'Title': 'World’s Cheapest 4G Phone ! *Jio Bharat K1*',
#   'Published_date': '2023-08-29T15:51:39Z',
#   'Views': '1447187',
#   'Likes': '49992',
#   'Comments': '1988'},
#  {'Title': 'I Used Smartphone with Voice !',
#   'Published_date': '2023-08-25T15:11:03Z',
#   'Views': '745517',
#   'Likes': '42192',
#   'Comments': '847'},
#  {'Title': 'Chandrayaan 3 will Make India Rich - India Makes History🇮🇳',
#   'Published_date': '2023-08-23T17:11:57Z',
#   'Views': '2683045',
#   'Likes': '174324',
#   'Comments': '4283'},
#  {'Title': '7 Majedaar Smartphone Gaming Gadgets you Should Try !',
#   'Published_date': '2023-08-21T17:38:35Z',
#   'Views': '2283038',
#   'Likes': '90874',
#   'Comments': '1550'},
#  {'Title': 'Apple iPhone 15 Series will be Different !',
#   'Published_date': '2023-08-19T02:30:16Z',
#   'Views': '3533452',
#   'Likes': '122431',
#   'Comments': '1762'},
#  {'Title': 'I Bought a ₹50 Lakh Screen !',
#   'Published_date': '2023-08-17T18:37:27Z',
#   'Views': '2422568',
#   'Likes': '123320',
#   'Comments': '2355'},
#  {'Title': 'This ₹15,000 Phone is Different ! *Tecno POVA 5 Pro 5G*',
#   'Published_date': '2023-08-14T07:30:52Z',
#   'Views': '2125121',
#   'Likes': '70883',
#   'Comments': '1352'},
#  {'Title': 'Samsung Galaxy Watch 6 Classic Unboxing & Quick Look !',
#   'Published_date': '2023-08-11T13:01:33Z',
#   'Views': '1032019',
#   'Likes': '30716',
#   'Comments': '716'},
#  {'Title': "India's First Driverless Car !",
#   'Published_date': '2023-08-10T15:31:49Z',
#   'Views': '2893325',
#   'Likes': '83357',
#   'Comments': '997'},
#  {'Title': 'Redmi 12 5G Unboxing & Quick Look ! *New budget King?*',
#   'Published_date': '2023-08-08T08:35:38Z',
#   'Views': '2209918',
#   'Likes': '62097',
#   'Comments': '2123'},
#  {'Title': 'Samsung Galaxy Z Fold 5 Review - Small but Important Upgrade !',
#   'Published_date': '2023-08-07T16:15:07Z',
#   'Views': '589912',
#   'Likes': '21074',
#   'Comments': '480'},
#  {'Title': 'Google Pixel Tablet Review - Why not in India?',
#   'Published_date': '2023-08-05T16:30:16Z',
#   'Views': '779578',
#   'Likes': '32453',
#   'Comments': '966'},
#  {'Title': 'OnePlus Nord 3 After 15 DAYS ! *Long Term Review*',
#   'Published_date': '2023-08-04T14:16:19Z',
#   'Views': '658432',
#   'Likes': '24252',
#   'Comments': '872'},
#  {'Title': 'World’s First Gaming Phone Under ₹20,000 !',
#   'Published_date': '2023-08-03T06:30:02Z',
#   'Views': '4954975',
#   'Likes': '185174',
#   'Comments': '3900'},
#  {'Title': 'Samsung Galaxy Z Flip 5 Review - Fully Changed !',
#   'Published_date': '2023-08-02T15:26:30Z',
#   'Views': '940210',
#   'Likes': '29249',
#   'Comments': '781'},
#  {'Title': "I Tried World's SMALLEST Gadgets !",
#   'Published_date': '2023-07-29T16:18:26Z',
#   'Views': '2867450',
#   'Likes': '76504',
#   'Comments': '1361'},
#  {'Title': "Samsung Z Fold 5 & Z Flip 5 First Impressions - What's New ?",
#   'Published_date': '2023-07-26T11:00:02Z',
#   'Views': '1177535',
#   'Likes': '40458',
#   'Comments': '1017'},
#  {'Title': 'Why I Started TechBurner? *QnA*',
#   'Published_date': '2023-07-25T16:29:59Z',
#   'Views': '1187343',
#   'Likes': '79511',
#   'Comments': '1552'},
#  {'Title': 'HP OMEN Transcend 16 Unboxing & Review ! *Premium Gaming*',
#   'Published_date': '2023-07-23T11:55:10Z',
#   'Views': '799264',
#   'Likes': '32154',
#   'Comments': '985'},
#  {'Title': 'Nothing Phone (2) - The secret strategy of Nothing?',
#   'Published_date': '2023-07-22T09:10:21Z',
#   'Views': '1552859',
#   'Likes': '55934',
#   'Comments': '1389'},
#  {'Title': '5 Best Smartphones Under ₹25,000 !',
#   'Published_date': '2023-07-19T15:53:40Z',
#   'Views': '2327153',
#   'Likes': '77495',
#   'Comments': '2860'},
#  {'Title': '₹50 Majedaar Online Gadgets !',
#   'Published_date': '2023-07-17T15:10:15Z',
#   'Views': '2011045',
#   'Likes': '85592',
#   'Comments': '1771'},
#  {'Title': 'Best Smartphones to buy on Amazon Prime Day !',
#   'Published_date': '2023-07-14T17:17:07Z',
#   'Views': '871018',
#   'Likes': '38652',
#   'Comments': '1402'},
#  {'Title': "Nothing Phone (2) Unboxing & First Impressions - What's New?",
#   'Published_date': '2023-07-11T15:42:42Z',
#   'Views': '2766694',
#   'Likes': '108511',
#   'Comments': '3295'},
#  {'Title': 'OPPO Reno10 Pro+ Unboxing & Quick Look - Almost There !',
#   'Published_date': '2023-07-10T17:34:59Z',
#   'Views': '1223972',
#   'Likes': '42117',
#   'Comments': '1304'},
#  {'Title': 'Samsung Galaxy M34 Unboxing ! *Best Under ₹20,000*',
#   'Published_date': '2023-07-07T10:03:19Z',
#   'Views': '1328904',
#   'Likes': '48214',
#   'Comments': '1864'},
#  {'Title': 'How Threads will DESTROY Twitter ? *Twitter vs Threads*',
#   'Published_date': '2023-07-06T16:47:30Z',
#   'Views': '1670306',
#   'Likes': '84777',
#   'Comments': '1487'},
#  {'Title': 'OnePlus Nord 3 Unboxing & Quick Look ! *Flagship Killer?*',
#   'Published_date': '2023-07-05T14:00:28Z',
#   'Views': '1704003',
#   'Likes': '57628',
#   'Comments': '2627'},
#  {'Title': 'This Midrange Phone has Special BGMI Features ! *iQOO Neo 7 Pro*',
#   'Published_date': '2023-07-04T08:57:11Z',
#   'Views': '1739085',
#   'Likes': '74043',
#   'Comments': '1845'},
#  {'Title': 'Motorola Razr 40 Ultra Unboxing ! *Majedaar Flip Features*',
#   'Published_date': '2023-07-03T12:34:05Z',
#   'Views': '1641146',
#   'Likes': '48906',
#   'Comments': '1045'},
#  {'Title': 'Can This Smartwatch Replace Phone ?',
#   'Published_date': '2023-06-29T12:31:29Z',
#   'Views': '903154',
#   'Likes': '34847',
#   'Comments': '942'},
#  {'Title': 'This Budget Smartwatch is Great Value for Money !',
#   'Published_date': '2023-06-22T14:03:15Z',
#   'Views': '2622473',
#   'Likes': '62140',
#   'Comments': '1780'},
#  {'Title': 'Apple MacBook Air 15” - First Time in 15 Years !',
#   'Published_date': '2023-06-20T15:21:02Z',
#   'Views': '1777933',
#   'Likes': '54381',
#   'Comments': '1221'},
#  {'Title': 'Why Smartphone are getting EXPENSIVE ?',
#   'Published_date': '2023-06-17T09:37:15Z',
#   'Views': '1076531',
#   'Likes': '50605',
#   'Comments': '1303'},
#  {'Title': 'Nothing Studio Tour Ft. Nothing Founder Carl Pei !',
#   'Published_date': '2023-06-13T12:43:41Z',
#   'Views': '2215114',
#   'Likes': '84034',
#   'Comments': '1393'},
#  {'Title': 'Realme 11 Pro - Completely Changed !',
#   'Published_date': '2023-06-09T07:25:55Z',
#   'Views': '1325036',
#   'Likes': '50152',
#   'Comments': '1355'},
#  {'Title': 'Can This Phone Save Realme ? *Realme 11 Pro Plus*',
#   'Published_date': '2023-06-08T09:10:21Z',
#   'Views': '2200109',
#   'Likes': '84493',
#   'Comments': '2004'},
#  {'Title': 'Samsung Galaxy F54 Unboxing - 108 MP OIS 📸 6000mAh 🔋',
#   'Published_date': '2023-06-06T15:49:30Z',
#   'Views': '1396947',
#   'Likes': '46912',
#   'Comments': '1512'},
#  {'Title': 'All New Apple VR is Here ! *Apple Vision Pro*',
#   'Published_date': '2023-06-06T05:57:32Z',
#   'Views': '2515780',
#   'Likes': '82628',
#   'Comments': '2135'},
#  {'Title': 'Trying 7 Weird Smartphone Life Hacks !',
#   'Published_date': '2023-06-04T10:28:08Z',
#   'Views': '1407242',
#   'Likes': '49142',
#   'Comments': '831'},
#  {'Title': 'How To Buy a Perfect Smartphone in 2023 !',
#   'Published_date': '2023-06-01T14:53:50Z',
#   'Views': '3113954',
#   'Likes': '110613',
#   'Comments': '2771'},
#  {'Title': '@Thugesh ka Studio Tour !',
#   'Published_date': '2023-05-31T08:15:00Z',
#   'Views': '2298091',
#   'Likes': '139380',
#   'Comments': '2517'},
#  {'Title': 'BGMI is Finally Here - Gameplay and Features !',
#   'Published_date': '2023-05-29T11:57:00Z',
#   'Views': '941015',
#   'Likes': '58143',
#   'Comments': '2003'},
#  {'Title': 'I Tried 7 IPL Gadgets !',
#   'Published_date': '2023-05-26T13:52:49Z',
#   'Views': '4030592',
#   'Likes': '98575',
#   'Comments': '1058'},
#  {'Title': 'Major Problem with Smartphones Right Now !',
#   'Published_date': '2023-05-25T13:18:05Z',
#   'Views': '1024878',
#   'Likes': '61090',
#   'Comments': '2436'},
#  {'Title': 'Moto Edge 40 Unboxing & Review ! New Flagship Killer?',
#   'Published_date': '2023-05-23T06:29:58Z',
#   'Views': '1792008',
#   'Likes': '52309',
#   'Comments': '1545'},
#  {'Title': 'Lava Agni 2 5G Unboxing ! Best Smartphone Under ₹20,000?',
#   'Published_date': '2023-05-22T06:29:57Z',
#   'Views': '1725338',
#   'Likes': '68666',
#   'Comments': '2171'},
#  {'Title': 'BGMI is Finally Coming Back - Confirmed ✅',
#   'Published_date': '2023-05-19T12:55:23Z',
#   'Views': '1722719',
#   'Likes': '128439',
#   'Comments': '3820'},
#  {'Title': '7 Majedaar Indian Innovations !',
#   'Published_date': '2023-05-18T15:00:47Z',
#   'Views': '1739592',
#   'Likes': '69941',
#   'Comments': '1168'},
#  {'Title': 'OPPO F23 5G Unboxing - I am Confused !',
#   'Published_date': '2023-05-15T09:13:59Z',
#   'Views': '1067118',
#   'Likes': '34389',
#   'Comments': '1259'},
#  {'Title': 'The Most Expensive TV I have ever Seen !',
#   'Published_date': '2023-05-13T16:18:17Z',
#   'Views': '3521358',
#   'Likes': '106921',
#   'Comments': '2502'},
#  {'Title': 'Google Pixel 7a Unboxing ! *Incomplete Upgrade?*',
#   'Published_date': '2023-05-11T15:51:11Z',
#   'Views': '1457191',
#   'Likes': '49541',
#   'Comments': '1094'},
#  {'Title': 'Poco F5 5G Unboxing - Flagship Performance Midrange Price !',
#   'Published_date': '2023-05-10T09:37:18Z',
#   'Views': '912606',
#   'Likes': '36914',
#   'Comments': '1774'},
#  {'Title': 'I Tried This Weird Electric Car ! *MG Comet*',
#   'Published_date': '2023-05-08T11:06:58Z',
#   'Views': '4739618',
#   'Likes': '99752',
#   'Comments': '3276'},
#  {'Title': "Xiaomi 13 Ultra - Don't Judge a Book by its Cover !",
#   'Published_date': '2023-05-05T14:43:08Z',
#   'Views': '1287402',
#   'Likes': '48545',
#   'Comments': '1583'},
#  {'Title': 'Why Smartphones Are Getting BORING?',
#   'Published_date': '2023-05-03T15:38:55Z',
#   'Views': '1281080',
#   'Likes': '63214',
#   'Comments': '1584'},
#  {'Title': 'Indian Government Banned 14 Apps !',
#   'Published_date': '2023-05-01T12:29:02Z',
#   'Views': '910876',
#   'Likes': '60894',
#   'Comments': '2186'},
#  {'Title': 'Can Your Laptop do This? *Samsung Galaxy Book 3 Pro 360*',
#   'Published_date': '2023-04-27T13:19:34Z',
#   'Views': '1241139',
#   'Likes': '48157',
#   'Comments': '1109'},
#  {'Title': 'vivo X90 Pro Unboxing & Review !',
#   'Published_date': '2023-04-26T08:07:10Z',
#   'Views': '1826604',
#   'Likes': '58465',
#   'Comments': '1434'},
#  {'Title': 'Why Marshall Speakers Are So Expensive?',
#   'Published_date': '2023-04-25T14:58:59Z',
#   'Views': '4524271',
#   'Likes': '125679',
#   'Comments': '3838'},
#  {'Title': '5 Weird Gadgets I Bought Online !',
#   'Published_date': '2023-04-23T06:55:18Z',
#   'Views': '2620996',
#   'Likes': '85352',
#   'Comments': '1367'},
#  {'Title': '5 Mast Mobile Photography Tricks that You Must Try !',
#   'Published_date': '2023-04-20T13:15:29Z',
#   'Views': '764729',
#   'Likes': '42876',
#   'Comments': '861'},
#  {'Title': "I Visited India's First Apple Store !",
#   'Published_date': '2023-04-17T13:46:42Z',
#   'Views': '6018937',
#   'Likes': '193440',
#   'Comments': '3597'},
#  {'Title': 'OPPO Find X6 Pro Unboxing & Quick Look !',
#   'Published_date': '2023-04-15T17:52:31Z',
#   'Views': '3431200',
#   'Likes': '95924',
#   'Comments': '2504'},
#  {'Title': "World's Most Powerful Smartphone ! *ROG 7 Ultimate*",
#   'Published_date': '2023-04-13T18:32:53Z',
#   'Views': '1609744',
#   'Likes': '77730',
#   'Comments': '1994'},
#  {'Title': 'vivo T2 5G Unboxing & Review ! New Midrange King ?',
#   'Published_date': '2023-04-11T08:29:54Z',
#   'Views': '1046309',
#   'Likes': '36922',
#   'Comments': '1304'},
#  {'Title': 'I Tried Cheapest Electric Cycle ! *Made in India*',
#   'Published_date': '2023-04-10T05:57:58Z',
#   'Views': '2230381',
#   'Likes': '59775',
#   'Comments': '1154'},
#  {'Title': '7 Dardnaak Tech Fails !',
#   'Published_date': '2023-04-07T14:10:10Z',
#   'Views': '1084475',
#   'Likes': '60677',
#   'Comments': '1049'},
#  {'Title': 'Why Apple Made NEW Yellow iPhone 14?',
#   'Published_date': '2023-04-05T15:22:17Z',
#   'Views': '2535141',
#   'Likes': '104978',
#   'Comments': '2266'},
#  {'Title': "We Made World's First Transparent Smartphone !",
#   'Published_date': '2023-04-01T06:30:17Z',
#   'Views': '5787637',
#   'Likes': '293111',
#   'Comments': '17271'},
#  {'Title': 'I Tried Futuristic AI Robots !',
#   'Published_date': '2023-03-30T15:41:54Z',
#   'Views': '1157548',
#   'Likes': '49725',
#   'Comments': '882'},
#  {'Title': '5 Best Smartphones Under ₹20,000 !',
#   'Published_date': '2023-03-27T14:45:27Z',
#   'Views': '3954021',
#   'Likes': '139240',
#   'Comments': '4135'},
#  {'Title': 'OnePlus Ace 2V Unboxing & Quick Look ! *Flagship Killer*',
#   'Published_date': '2023-03-25T09:51:48Z',
#   'Views': '1610142',
#   'Likes': '60169',
#   'Comments': '1602'},
#  {'Title': 'You Are Charging Your Phone Wrong ! *Charging Tricks*',
#   'Published_date': '2023-03-23T15:08:53Z',
#   'Views': '2371891',
#   'Likes': '121081',
#   'Comments': '2795'},
#  {'Title': 'I Tried Shark Tank Products !',
#   'Published_date': '2023-03-21T10:33:29Z',
#   'Views': '5533917',
#   'Likes': '178486',
#   'Comments': '2212'},
#  {'Title': 'Samsung Galaxy F14 5G Unboxing - 50 MP 📸 6000mAh🔋@ ₹12,990 !',
#   'Published_date': '2023-03-20T06:32:21Z',
#   'Views': '1485952',
#   'Likes': '50963',
#   'Comments': '1505'},
#  {'Title': 'Samsung A54 & A34 Unboxing & Quick Look !',
#   'Published_date': '2023-03-17T15:39:45Z',
#   'Views': '2267278',
#   'Likes': '70706',
#   'Comments': '2213'},
#  {'Title': 'Indian Govt. Can STOP Pre-Installed Apps !',
#   'Published_date': '2023-03-14T15:17:07Z',
#   'Views': '590984',
#   'Likes': '48309',
#   'Comments': '1353'},
#  {'Title': 'POCO X5 5G Unboxing  - 120Hz AMOLED📱 5000mAh🔋!',
#   'Published_date': '2023-03-14T07:30:01Z',
#   'Views': '1213392',
#   'Likes': '48132',
#   'Comments': '1722'},
#  {'Title': 'The Game Changer Flip Phone ! *OPPO Find N2 Flip*',
#   'Published_date': '2023-03-13T06:33:06Z',
#   'Views': '1951126',
#   'Likes': '65993',
#   'Comments': '2302'},
#  {'Title': 'Most Affordable Apple Computer ! *Mac Mini M2*',
#   'Published_date': '2023-03-12T12:22:11Z',
#   'Views': '1507498',
#   'Likes': '51753',
#   'Comments': '1185'},
#  {'Title': 'Moto g73 5G Unboxing & Quick Look !',
#   'Published_date': '2023-03-10T06:34:41Z',
#   'Views': '816047',
#   'Likes': '35005',
#   'Comments': '1224'},
#  {'Title': 'TechBurner Girlfriend Revealed? *10M QnA*',
#   'Published_date': '2023-03-08T10:30:13Z',
#   'Views': '1763148',
#   'Likes': '161648',
#   'Comments': '4164'},
#  {'Title': 'Why Rolls Royce Cars Are So Expensive?',
#   'Published_date': '2023-03-04T13:51:42Z',
#   'Views': '7583100',
#   'Likes': '238085',
#   'Comments': '3895'},
#  {'Title': 'Xiaomi 13 Pro 5G Unboxing & Review ! *Camera King*',
#   'Published_date': '2023-03-02T07:41:23Z',
#   'Views': '967765',
#   'Likes': '41221',
#   'Comments': '1200'},
#  {'Title': 'vivo V27 Pro Unboxing & Quick Look ! *Camera Magic*',
#   'Published_date': '2023-03-01T07:00:02Z',
#   'Views': '1825281',
#   'Likes': '62726',
#   'Comments': '1252'},
#  {'Title': 'I Tried Special OnePlus Smartphone ! *Liquid Cooling*',
#   'Published_date': '2023-02-27T09:37:11Z',
#   'Views': '1060224',
#   'Likes': '43796',
#   'Comments': '906'},
#  {'Title': 'Our Biggest Collab Is Finally Here ! *Layers X Marvel*',
#   'Published_date': '2023-02-25T10:30:07Z',
#   'Views': '848707',
#   'Likes': '66062',
#   'Comments': '3324'},
#  {'Title': "World's First Lens Changing Smartphone !",
#   'Published_date': '2023-02-22T16:04:05Z',
#   'Views': '829542',
#   'Likes': '41978',
#   'Comments': '1082'},
#  {'Title': 'OnePlus 11R 5G Unboxing & Review ! *Flagship Killer?*',
#   'Published_date': '2023-02-21T10:12:07Z',
#   'Views': '1669954',
#   'Likes': '60067',
#   'Comments': '1400'},
#  {'Title': 'OnePlus 11 5G In-Depth Camera Review ! *Hasselblad Magic?*',
#   'Published_date': '2023-02-16T15:40:02Z',
#   'Views': '1338374',
#   'Likes': '47669',
#   'Comments': '1302'},
#  {'Title': 'I Covered my BMW with Layers Skin !',
#   'Published_date': '2023-02-15T16:21:36Z',
#   'Views': '3074581',
#   'Likes': '145861',
#   'Comments': '3125'},
#  {'Title': 'Why Companies make SPECIAL EDITION Phone ? *ROG 6 Diablo Edition*',
#   'Published_date': '2023-02-14T15:51:59Z',
#   'Views': '1839476',
#   'Likes': '84531',
#   'Comments': '1445'},
#  {'Title': 'iQOO Neo 7 Unboxing ! *Best Phone under ₹30,000?*',
#   'Published_date': '2023-02-13T11:54:01Z',
#   'Views': '905335',
#   'Likes': '46787',
#   'Comments': '1394'},
#  {'Title': 'This Gaming Phone has Special PubG Features !',
#   'Published_date': '2023-02-12T09:25:11Z',
#   'Views': '4113139',
#   'Likes': '123858',
#   'Comments': '2497'},
#  {'Title': "World's Fastest Electric Car ! *Tesla Model S Plaid*",
#   'Published_date': '2023-02-10T12:34:44Z',
#   'Views': '3959469',
#   'Likes': '125761',
#   'Comments': '1619'},
#  {'Title': 'Samsung S23 Ultra Review -  Best Android Phone?',
#   'Published_date': '2023-02-09T16:23:56Z',
#   'Views': '2822621',
#   'Likes': '103170',
#   'Comments': '2208'},
#  {'Title': 'India’s Most Affordable Smartphone ! *Moto e13*',
#   'Published_date': '2023-02-08T06:36:45Z',
#   'Views': '885959',
#   'Likes': '35298',
#   'Comments': '1368'},
#  {'Title': 'OnePlus 11 5G Unboxing & Review ! *Different OnePlus*',
#   'Published_date': '2023-02-07T15:17:42Z',
#   'Views': '1291612',
#   'Likes': '54135',
#   'Comments': '1637'},
#  {'Title': 'Indian Government Banned 230 Apps !',
#   'Published_date': '2023-02-06T17:11:17Z',
#   'Views': '1932428',
#   'Likes': '162647',
#   'Comments': '6057'},
#  {'Title': 'Infinix Zero 5G Turbo Unboxing ! *Best Budget Performance?*',
#   'Published_date': '2023-02-04T06:30:02Z',
#   'Views': '669798',
#   'Likes': '35161',
#   'Comments': '991'},
#  {'Title': 'All New Samsung S23 Series Is Here !',
#   'Published_date': '2023-02-02T14:02:14Z',
#   'Views': '2245633',
#   'Likes': '112621',
#   'Comments': '2195'},
#  {'Title': 'This is the Future of Gaming !',
#   'Published_date': '2023-02-01T16:53:14Z',
#   'Views': '1136577',
#   'Likes': '50153',
#   'Comments': '937'},
#  {'Title': "World's First Color Changing Car !",
#   'Published_date': '2023-01-29T14:07:15Z',
#   'Views': '2165894',
#   'Likes': '68980',
#   'Comments': '1043'},
#  {'Title': 'Our Most Expensive Mystery Box ! *25 Lakhs*',
#   'Published_date': '2023-01-26T06:30:17Z',
#   'Views': '7076599',
#   'Likes': '255652',
#   'Comments': '3427'},
#  {'Title': "World's First Moving Camera Smartphone !",
#   'Published_date': '2023-01-23T16:34:02Z',
#   'Views': '2219232',
#   'Likes': '82850',
#   'Comments': '1517'},
#  {'Title': 'This is My Most Expensive Unboxing ! *Private Jet*',
#   'Published_date': '2023-01-20T14:36:42Z',
#   'Views': '3715705',
#   'Likes': '184966',
#   'Comments': '3712'},
#  {'Title': 'Dell Alienware m15 R7 Review ! *Powerful Gaming*',
#   'Published_date': '2023-01-17T16:57:56Z',
#   'Views': '1496754',
#   'Likes': '62473',
#   'Comments': '1662'},
#  {'Title': 'Samsung Galaxy A14 5G Unboxing ! *New Year, New Samsung*',
#   'Published_date': '2023-01-15T09:36:43Z',
#   'Views': '1650796',
#   'Likes': '63117',
#   'Comments': '1556'},
#  {'Title': 'All New OnePlus 11 5G Unboxing & Quick Look ! *Different OnePlus*',
#   'Published_date': '2023-01-11T18:13:28Z',
#   'Views': '1988904',
#   'Likes': '82303',
#   'Comments': '3115'},
#  {'Title': "India's Fastest Android Smartphone ! *iQOO 11 5G*",
#   'Published_date': '2023-01-10T07:14:24Z',
#   'Views': '2378464',
#   'Likes': '83775',
#   'Comments': '1595'},
#  {'Title': 'I Tried this Special Edition Phone ! *Nubia Z40 Pro*',
#   'Published_date': '2023-01-07T06:31:14Z',
#   'Views': '2467741',
#   'Likes': '101465',
#   'Comments': '1816'},
#  {'Title': 'Redmi Note 12 5G Unboxing ! *Budget King?*',
#   'Published_date': '2023-01-05T09:37:59Z',
#   'Views': '1076510',
#   'Likes': '42746',
#   'Comments': '1687'},
#  {'Title': "I Made World's Biggest Hologram !",
#   'Published_date': '2023-01-04T16:53:49Z',
#   'Views': '1834432',
#   'Likes': '102002',
#   'Comments': '3714'},
#  {'Title': 'Redmi Note 12 Pro Plus 5G Indian Unit Unboxing & Quick Look - 200MP 📷 & 120W🔋 !',
#   'Published_date': '2023-01-03T05:30:04Z',
#   'Views': '1386171',
#   'Likes': '52459',
#   'Comments': '2231'},
#  {'Title': 'Xiaomi 13 Pro 5G - Unboxing & Quick Look ! *Flagship King*',
#   'Published_date': '2022-12-31T11:34:12Z',
#   'Views': '1644137',
#   'Likes': '59430',
#   'Comments': '1817'},
#  {'Title': 'Xiaomi 13 5G Unboxing & Quick Look ! *Camera Magic*',
#   'Published_date': '2022-12-30T13:08:16Z',
#   'Views': '1116649',
#   'Likes': '53294',
#   'Comments': '1730'},
#  {'Title': 'Noise ColorFit Pro Alpha Review ! *Value for Money*',
#   'Published_date': '2022-12-28T14:15:12Z',
#   'Views': '1882368',
#   'Likes': '70714',
#   'Comments': '1766'},
#  {'Title': '5 Best Smartphones Under ₹15,000 !',
#   'Published_date': '2022-12-27T17:11:00Z',
#   'Views': '3737909',
#   'Likes': '141164',
#   'Comments': '3804'},
#  {'Title': "World's Cheapest Electric Car ! *Sasti Masti*",
#   'Published_date': '2022-12-24T04:30:04Z',
#   'Views': '3014335',
#   'Likes': '99072',
#   'Comments': '2089'},
#  {'Title': 'Redmi Note 12 Pro Plus Unboxing & Quick Look ! *Best Value?*',
#   'Published_date': '2022-12-22T04:00:07Z',
#   'Views': '2101937',
#   'Likes': '71823',
#   'Comments': '1461'},
#  {'Title': 'Infinix Zero Ultra Unboxing and Quick Look - 200MP 📷 & 180W🔋 !',
#   'Published_date': '2022-12-20T18:15:08Z',
#   'Views': '1753843',
#   'Likes': '65737',
#   'Comments': '1525'},
#  {'Title': 'Most Powerful Android Smartphone ! *Teaser*',
#   'Published_date': '2022-12-17T15:52:14Z',
#   'Views': '789081',
#   'Likes': '51685',
#   'Comments': '1353'},
#  {'Title': 'Top Deals on  Smartphones during Flipkart Big Saving Days !',
#   'Published_date': '2022-12-16T03:00:04Z',
#   'Views': '1062660',
#   'Likes': '54030',
#   'Comments': '1235'},
#  {'Title': 'Realme 10 Pro Plus Unboxing and Quick Look - Great Phone, One Problem !',
#   'Published_date': '2022-12-14T16:33:29Z',
#   'Views': '1677971',
#   'Likes': '75744',
#   'Comments': '1682'},
#  {'Title': "I Tried Audi's Fastest Electric Car ! *E-tron GT RS*",
#   'Published_date': '2022-12-12T13:30:33Z',
#   'Views': '4116601',
#   'Likes': '144254',
#   'Comments': '2796'},
#  {'Title': '7 Majedaar Gadgets Under ₹100 !',
#   'Published_date': '2022-12-10T08:06:41Z',
#   'Views': '5018333',
#   'Likes': '189353',
#   'Comments': '3096'},
#  {'Title': '7 Weird Smartphone Life Hacks !',
#   'Published_date': '2022-12-07T17:13:42Z',
#   'Views': '3026856',
#   'Likes': '112997',
#   'Comments': '1501'},
#  {'Title': "I Tried Apple's Secret Product ! *T-Shirt*",
#   'Published_date': '2022-12-03T15:38:29Z',
#   'Views': '1148494',
#   'Likes': '65805',
#   'Comments': '1461'},
#  {'Title': 'Infinix HOT 20 Unboxing & Review! *Budget 5G*',
#   'Published_date': '2022-12-02T13:33:21Z',
#   'Views': '736270',
#   'Likes': '39316',
#   'Comments': '1146'},
#  {'Title': "Don't Buy Wireless Earphone before Watching this Video! *Big Comparison 2022*",
#   'Published_date': '2022-11-29T16:32:25Z',
#   'Views': '5986424',
#   'Likes': '171387',
#   'Comments': '4058'},
# ...
#   'Comments': '3131'},
#  {'Title': '5 Weird Smartphone Gadgets !',
#   'Published_date': '2019-05-20T15:48:28Z',
#   'Views': '1292642',
#   'Likes': '52600',
#   'Comments': '1580'},
#  {'Title': '8 ZORDAR APPS THAT YOU MUST HAVE ON YOUR PHONE !',
#   'Published_date': '2019-05-19T17:24:40Z',
#   'Views': '819117',
#   'Likes': '49680',
#   'Comments': '4430'},
#  {'Title': "DON'T BUY ONE PLUS 7 PRO BEFORE WATCHING THIS VIDEO !",
#   'Published_date': '2019-05-18T17:57:47Z',
#   'Views': '1517115',
#   'Likes': '67517',
#   'Comments': '4530'},
#  {'Title': 'Zenfone 6 | Honest First Impressions',
#   'Published_date': '2019-05-18T08:52:59Z',
#   'Views': '1301962',
#   'Likes': '62194',
#   'Comments': '2421'},
#  {'Title': '8 SELFIE Tricks That Every Smartphone User Should Know !',
#   'Published_date': '2019-05-17T17:15:53Z',
#   'Views': '4126951',
#   'Likes': '171885',
#   'Comments': '3354'},
#  {'Title': 'One Plus 7 Pro | Honest Opinion',
#   'Published_date': '2019-05-15T17:18:40Z',
#   'Views': '351456',
#   'Likes': '20005',
#   'Comments': '1999'},
#  {'Title': 'Why Midrange Phones Are Better Than Flagships?',
#   'Published_date': '2019-05-10T17:27:25Z',
#   'Views': '798267',
#   'Likes': '50482',
#   'Comments': '1582'},
#  {'Title': 'MEHENGE PHONES KA ASLI SACH !',
#   'Published_date': '2019-05-08T18:28:58Z',
#   'Views': '181423',
#   'Likes': '14535',
#   'Comments': '794'},
#  {'Title': 'I Tried this Weird Camera !',
#   'Published_date': '2019-05-05T17:39:29Z',
#   'Views': '1272772',
#   'Likes': '66007',
#   'Comments': '2236'},
#  {'Title': 'PUBG ON A Smart TV ? *Samsung TV Feature Highlight*',
#   'Published_date': '2019-05-02T15:06:23Z',
#   'Views': '1301340',
#   'Likes': '49960',
#   'Comments': '1449'},
#  {'Title': '6 Cool Apps That you Should TRY !',
#   'Published_date': '2019-04-30T17:49:33Z',
#   'Views': '1739566',
#   'Likes': '100608',
#   'Comments': '2140'},
#  {'Title': 'Trying 5 Weird SmartPhone Life Hacks #ASLI SACH',
#   'Published_date': '2019-04-26T16:41:52Z',
#   'Views': '7746301',
#   'Likes': '356996',
#   'Comments': '5367'},
#  {'Title': 'Realme 3 Pro | Honest Impressions',
#   'Published_date': '2019-04-23T16:26:09Z',
#   'Views': '623358',
#   'Likes': '40384',
#   'Comments': '2569'},
#  {'Title': "DON'T BUY EARPHONES BEFORE WATCHING THIS VIDEO !",
#   'Published_date': '2019-04-18T14:00:12Z',
#   'Views': '2856564',
#   'Likes': '155323',
#   'Comments': '5043'},
#  {'Title': 'TECHBURNER QnA | My SECRET FANFEST PERFORMANCE ?',
#   'Published_date': '2019-04-08T14:18:08Z',
#   'Views': '186851',
#   'Likes': '14819',
#   'Comments': '1114'},
#  {'Title': "DON'T PLAY PUBG BEFORE WATCHING THIS VIDEO !",
#   'Published_date': '2019-04-04T18:15:03Z',
#   'Views': '1543187',
#   'Likes': '113620',
#   'Comments': '5362'},
#  {'Title': 'TURN ANY PHONE INTO FLYING PHONE FOR JUST 50 RS ! *drone trick*',
#   'Published_date': '2019-04-01T18:46:38Z',
#   'Views': '3542191',
#   'Likes': '238740',
#   'Comments': '10127'},
#  {'Title': '5 More WEIRD Gadgets that You Can Buy Online !',
#   'Published_date': '2019-03-31T16:30:35Z',
#   'Views': '2273435',
#   'Likes': '114377',
#   'Comments': '2598'},
#  {'Title': 'This App Will CHANGE The WAY You Message!',
#   'Published_date': '2019-03-27T15:41:48Z',
#   'Views': '144448',
#   'Likes': '8737',
#   'Comments': '1229'},
#  {'Title': 'Nokia Phone Leaking Data, Redmi Note 7 pro Smoke Test, Apple Upgrade Problem, Realme 3 Pro #TTM',
#   'Published_date': '2019-03-25T17:31:02Z',
#   'Views': '214153',
#   'Likes': '15587',
#   'Comments': '1400'},
#  {'Title': 'Spotify vs Saavn vs Youtube Music vs Amazon Music !',
#   'Published_date': '2019-03-20T17:12:53Z',
#   'Views': '813076',
#   'Likes': '44652',
#   'Comments': '4345'},
#  {'Title': 'I BOUGHT "AIR" ON AMAZON FOR Rs 1000 | *pure oxygen*',
#   'Published_date': '2019-03-18T17:50:29Z',
#   'Views': '1792620',
#   'Likes': '107889',
#   'Comments': '4135'},
#  {'Title': 'My MOST SPECIAL UNBOXING | #DilKiBaat 🔥🔥🔥',
#   'Published_date': '2019-03-11T12:47:25Z',
#   'Views': '254389',
#   'Likes': '23111',
#   'Comments': '2268'},
#  {'Title': 'Redmi Note 7 Pro | BAWAL Phone But Ek DIKKAT !',
#   'Published_date': '2019-03-08T14:00:53Z',
#   'Views': '669076',
#   'Likes': '34856',
#   'Comments': '1940'},
#  {'Title': 'Realme 3 | Honest Impressions',
#   'Published_date': '2019-03-04T17:52:17Z',
#   'Views': '514034',
#   'Likes': '27200',
#   'Comments': '2235'},
#  {'Title': 'Samsung Galaxy A50 | 20,000 Me Tabahi ?',
#   'Published_date': '2019-03-02T17:39:25Z',
#   'Views': '870380',
#   'Likes': '37660',
#   'Comments': '2861'},
#  {'Title': 'Samsung Galaxy M30 | Worthy Upgrade?',
#   'Published_date': '2019-03-01T18:09:14Z',
#   'Views': '254860',
#   'Likes': '13310',
#   'Comments': '1701'},
#  {'Title': 'Galaxy S10+ | Paisa Wasool?',
#   'Published_date': '2019-02-28T17:32:06Z',
#   'Views': '3670895',
#   'Likes': '120288',
#   'Comments': '5486'},
#  {'Title': 'Nokia 5 Camera Phone Released, Samsung + Huawei Foldable Phone, Samsung M30, HoloLens 2 #Tabahi',
#   'Published_date': '2019-02-25T18:56:44Z',
#   'Views': '341749',
#   'Likes': '30909',
#   'Comments': '2228'},
#  {'Title': 'This Might Be The FUTURE of BATTERIES !',
#   'Published_date': '2019-02-23T17:25:02Z',
#   'Views': '1095616',
#   'Likes': '64949',
#   'Comments': '2909'},
#  {'Title': 'Vivo V15 Pro Honest Opinion !',
#   'Published_date': '2019-02-20T18:02:58Z',
#   'Views': '719912',
#   'Likes': '21965',
#   'Comments': '1786'},
#  {'Title': '6 MAST TIMEPASS Apps That you Should TRY !',
#   'Published_date': '2019-02-19T17:58:48Z',
#   'Views': '612140',
#   'Likes': '31280',
#   'Comments': '1524'},
#  {'Title': 'TikTok Ban, Redmi Note 7 REAL Test, Charge with Wifi, Realme 3, Uber Boat, Android Virus #TTM',
#   'Published_date': '2019-02-17T16:36:06Z',
#   'Views': '297859',
#   'Likes': '19467',
#   'Comments': '1348'},
#  {'Title': 'How To Take CREATIVE DSLR like Photos at NIGHT with any Mobile!',
#   'Published_date': '2019-02-15T18:44:49Z',
#   'Views': '590183',
#   'Likes': '47089',
#   'Comments': '1810'},
#  {'Title': '5 PERFORMANCE TRICKS THAT YOU MUST TRY + PLAY PUB G SMOOTHLY!',
#   'Published_date': '2019-02-11T17:22:20Z',
#   'Views': '1408711',
#   'Likes': '107102',
#   'Comments': '3298'},
#  {'Title': '5 WEIRD Gadgets that You Can Buy Online !',
#   'Published_date': '2019-02-09T18:46:12Z',
#   'Views': '4666458',
#   'Likes': '270512',
#   'Comments': '5768'},
#  {'Title': 'CRAZY PRICES ON ASUS PHONES ! FLIPKART SALE 6-9th FEB !',
#   'Published_date': '2019-02-05T10:51:33Z',
#   'Views': '138276',
#   'Likes': '11714',
#   'Comments': '1837'},
#  {'Title': '8 ZORDAR APPS THAT YOU MUST TRY !',
#   'Published_date': '2019-02-04T16:02:31Z',
#   'Views': '815819',
#   'Likes': '39446',
#   'Comments': '3846'},
#  {'Title': 'Redmi Note 7 Bend Test ,32" TV for Rs4999,Samsung M20 Issue ,Vivo Apex 2019, Iphone Price Drop #TTM',
#   'Published_date': '2019-02-02T15:25:16Z',
#   'Views': '344154',
#   'Likes': '23048',
#   'Comments': '2269'},
#  {'Title': 'EDIT AMAZING PHOTOS ONLY USING MOBILE ! Lightroom Tutorial',
#   'Published_date': '2019-01-31T14:42:30Z',
#   'Views': '3888697',
#   'Likes': '236970',
#   'Comments': '3641'},
#  {'Title': 'SAMSUNG GALAXY M10 | Performance, Camera, Battery Ka Sach !',
#   'Published_date': '2019-01-30T18:25:16Z',
#   'Views': '256025',
#   'Likes': '11203',
#   'Comments': '1310'},
#  {'Title': 'SAMSUNG GALAXY M20 | ASLI MADE IN INDIA ?',
#   'Published_date': '2019-01-29T18:25:02Z',
#   'Views': '1228211',
#   'Likes': '44826',
#   'Comments': '3464'},
#  {'Title': 'Samsung Galaxy M20 & M10 | Unboxing and Giveaway !',
#   'Published_date': '2019-01-28T13:44:23Z',
#   'Views': '312556',
#   'Likes': '43679',
#   'Comments': '32293'},
#  {'Title': 'Foldable Phones ka Tahalka ! ft Xiaomi,Motorola,Samsung !',
#   'Published_date': '2019-01-25T18:11:44Z',
#   'Views': '489756',
#   'Likes': '28786',
#   'Comments': '1278'},
#  {'Title': 'Android 10 | Tabahi Machne Wali hai 🔥🔥🔥',
#   'Published_date': '2019-01-21T18:05:35Z',
#   'Views': '288153',
#   'Likes': '18256',
#   'Comments': '1763'},
#  {'Title': "India's New Snapdragon Killer ? India's Shakti vs Snapdragon Full Khulasa!",
#   'Published_date': '2019-01-19T14:00:04Z',
#   'Views': '807116',
#   'Likes': '54183',
#   'Comments': '3438'},
#  {'Title': '5 WEIRD INNOVATIVE TECHNOLOGY !',
#   'Published_date': '2019-01-17T17:46:42Z',
#   'Views': '473401',
#   'Likes': '31119',
#   'Comments': '1091'},
#  {'Title': 'Redmi 7 Pro Camera , Nokia Display Hole Phone, Android ki Dikkat, Iphone 11 Leaked, Samsung s10 #TTM',
#   'Published_date': '2019-01-13T14:30:00Z',
#   'Views': '202700',
#   'Likes': '17710',
#   'Comments': '1660'},
#  {'Title': 'INTERNET KA BAWAL !',
#   'Published_date': '2019-01-11T17:35:01Z',
#   'Views': '134966',
#   'Likes': '10580',
#   'Comments': '1234'},
#  {'Title': 'I Switched to the iPhone 4 from a FLAGSHIP ! *8 Year old phone in 2019*',
#   'Published_date': '2019-01-10T17:08:48Z',
#   'Views': '1158536',
#   'Likes': '59501',
#   'Comments': '3444'},
#  {'Title': '5 AWESOME Android Apps that you Must Try ! Part #7',
#   'Published_date': '2019-01-07T06:30:00Z',
#   'Views': '334314',
#   'Likes': '20459',
#   'Comments': '1044'},
#  {'Title': 'Iphone BAN Might be Real ! FULL STORY | Lawsuits + Problems',
#   'Published_date': '2019-01-02T18:01:20Z',
#   'Views': '171241',
#   'Likes': '13595',
#   'Comments': '1046'},
#  {'Title': 'TECH BURNER REWIND 2018 + Reading Mean Comments !',
#   'Published_date': '2018-12-31T14:38:32Z',
#   'Views': '171371',
#   'Likes': '18224',
#   'Comments': '2490'},
#  {'Title': 'TURN ANY PHONE INTO IPHONE XS GOLD for Just Rs 20 ! *Mobile Skin Trick*',
#   'Published_date': '2018-12-28T08:40:27Z',
#   'Views': '6433693',
#   'Likes': '288276',
#   'Comments': '7711'},
#  {'Title': 'FUCHSIA OS MIGHT REPLACE ANDROID !!!',
#   'Published_date': '2018-12-24T18:38:32Z',
#   'Views': '454021',
#   'Likes': '25595',
#   'Comments': '2751'},
#  {'Title': 'Iphone BAN , One Plus 7 Leak, Lenovo 12GB Ram Phone,Pub G BAN, Samsung S10 Leak #TTM',
#   'Published_date': '2018-12-22T15:26:20Z',
#   'Views': '326007',
#   'Likes': '27180',
#   'Comments': '1977'},
#  {'Title': 'I Switched to the Zenfone Max M2 from a Flagship!',
#   'Published_date': '2018-12-20T06:44:25Z',
#   'Views': '205087',
#   'Likes': '12988',
#   'Comments': '1837'},
#  {'Title': '5 AMAZING SMARTPHONE GADGETS UNDER 50 Rs !',
#   'Published_date': '2018-12-18T18:49:51Z',
#   'Views': '6252337',
#   'Likes': '343809',
#   'Comments': '8156'},
#  {'Title': 'Can a 15,000 Rs Phone Shoot DSLR like Youtube Video ? ft. Zenfone Max Pro M2',
#   'Published_date': '2018-12-16T17:29:32Z',
#   'Views': '589217',
#   'Likes': '27802',
#   'Comments': '1497'},
#  {'Title': 'Zenfone Max M2 | Rs 10,000 me Masti ?',
#   'Published_date': '2018-12-13T18:36:26Z',
#   'Views': '115379',
#   'Likes': '7303',
#   'Comments': '811'},
#  {'Title': 'Midrange Smartphone Cameras Ka Sach ft. Realme U1',
#   'Published_date': '2018-12-11T17:00:32Z',
#   'Views': '124761',
#   'Likes': '10171',
#   'Comments': '907'},
#  {'Title': 'Zenfone Max Pro M2 | 13 Hazar me Tabahi !',
#   'Published_date': '2018-12-11T12:25:40Z',
#   'Views': '616434',
#   'Likes': '31025',
#   'Comments': '2246'},
#  {'Title': '5 AMAZING Android Apps that you Must Try ! Part #6',
#   'Published_date': '2018-12-08T18:19:31Z',
#   'Views': '991243',
#   'Likes': '55592',
#   'Comments': '1253'},
#  {'Title': 'Oppo R17 Pro | PAISA WASTE ya Wasool ???',
#   'Published_date': '2018-12-05T18:46:12Z',
#   'Views': '109485',
#   'Likes': '7826',
#   'Comments': '674'},
#  {'Title': "Samsung's Secret Galaxy S10 Project ! 🔥 Finally???",
#   'Published_date': '2018-12-03T18:37:44Z',
#   'Views': '201532',
#   'Likes': '12922',
#   'Comments': '1052'},
#  {'Title': '5 Weird Gadgets on Amazon under 500 Rs !',
#   'Published_date': '2018-12-01T13:30:00Z',
#   'Views': '4524301',
#   'Likes': '187766',
#   'Comments': '4586'},
#  {'Title': 'IS THIS THE FUTURE OF GAMING?',
#   'Published_date': '2018-11-29T18:58:13Z',
#   'Views': '397137',
#   'Likes': '22123',
#   'Comments': '1261'},
#  {'Title': 'Real Me U1 | Performance Camera Battery ka Sach !',
#   'Published_date': '2018-11-28T19:03:11Z',
#   'Views': '420858',
#   'Likes': '22551',
#   'Comments': '1611'},
#  {'Title': 'SMARTPHONE MULTI CAMERA SETUP KA ASLI SACH!',
#   'Published_date': '2018-11-26T18:38:37Z',
#   'Views': '359677',
#   'Likes': '23609',
#   'Comments': '1558'},
#  {'Title': 'Nokia 9 with 5 Cameras,Redmi Note 6 Pro, Zenfone Max Pro M2 , Real Me U1, PubG #TechThatMatters',
#   'Published_date': '2018-11-23T18:14:55Z',
#   'Views': '110061',
#   'Likes': '8897',
#   'Comments': '1242'},
#  {'Title': 'THIS IS INSANE TECH!',
#   'Published_date': '2018-11-17T18:09:33Z',
#   'Views': '853520',
#   'Likes': '54616',
#   'Comments': '1999'},
#  {'Title': 'SMARTPHONE PROCESSORS KA ASLI SACH !',
#   'Published_date': '2018-11-10T14:00:07Z',
#   'Views': '120151',
#   'Likes': '10070',
#   'Comments': '956'},
#  {'Title': 'THE REAL REASON WHY ONEPLUS REMOVED THE HEADPHONE JACK!',
#   'Published_date': '2018-11-08T19:00:29Z',
#   'Views': '373027',
#   'Likes': '16563',
#   'Comments': '844'},
#  {'Title': 'Best Smartphones from Rs 5,000 to Rs 20,000 ? Best Phone for All Budget!',
#   'Published_date': '2018-11-06T13:00:09Z',
#   'Views': '243351',
#   'Likes': '14834',
#   'Comments': '1162'},
#  {'Title': 'APPLE HATER REVIEWS MACBOOK AIR *2017*',
#   'Published_date': '2018-11-02T18:58:05Z',
#   'Views': '803091',
#   'Likes': '34659',
#   'Comments': '1905'},
#  {'Title': '5 Awesome Android Apps that you Must Try !',
#   'Published_date': '2018-10-30T19:00:36Z',
#   'Views': '746589',
#   'Likes': '35215',
#   'Comments': '1643'},
#  {'Title': "Samsung's Secret Galaxy S10 Project ! Confirmed?",
#   'Published_date': '2018-10-27T18:46:36Z',
#   'Views': '679476',
#   'Likes': '28810',
#   'Comments': '2096'},
#  {'Title': 'THE REAL PROBLEM WITH APPLE IN INDIA!',
#   'Published_date': '2018-10-25T18:42:58Z',
#   'Views': '843763',
#   'Likes': '49694',
#   'Comments': '2136'},
#  {'Title': 'WATCH THIS BEFORE BUYING A SUPER BUDGET PHONE!',
#   'Published_date': '2018-10-22T17:49:25Z',
#   'Views': '86387',
#   'Likes': '7299',
#   'Comments': '1227'},
#  {'Title': 'DONT BUY A CAMERA FOR VIDEO BEFORE WATCHING THIS VIDEO!',
#   'Published_date': '2018-10-20T18:21:33Z',
#   'Views': '1237444',
#   'Likes': '61396',
#   'Comments': '2231'},
#  {'Title': 'Zenfone Lite aur Zenfone Max | Saari Confusion Khatam',
#   'Published_date': '2018-10-17T18:54:32Z',
#   'Views': '63331',
#   'Likes': '5040',
#   'Comments': '719'},
#  {'Title': 'AMAZING MID SALE GADGET DEALS ON FLIPKART BIG BILLION DAY & AMAZON GREAT INDIAN SALE',
#   'Published_date': '2018-10-12T18:25:38Z',
#   'Views': '138682',
#   'Likes': '9003',
#   'Comments': '1034'},
#  {'Title': 'I DID NOT PLAN THIS! *TABAHI*',
#   'Published_date': '2018-10-07T18:37:20Z',
#   'Views': '137519',
#   'Likes': '13609',
#   'Comments': '1961'},
#  {'Title': 'THIS IS WHY iPHONES ARE EXPENSIVE IN INDIA! #PRICEGATE',
#   'Published_date': '2018-10-04T18:19:59Z',
#   'Views': '3206749',
#   'Likes': '150938',
#   'Comments': '4123'},
#  {'Title': '5 AMAZING Mobile Photography Tricks for DSLR like Photos!',
#   'Published_date': '2018-10-01T18:15:24Z',
#   'Views': '3336276',
#   'Likes': '121091',
#   'Comments': '3714'},
#  {'Title': 'RealMe 2 Pro Tabahi Phone 🔥 | Vivo V11 Pro Killer?',
#   'Published_date': '2018-09-27T09:46:49Z',
#   'Views': '266957',
#   'Likes': '15328',
#   'Comments': '1767'},
#  {'Title': 'I DID NOT EXPECT THIS! (QnA+ Giveaway)',
#   'Published_date': '2018-09-25T18:18:33Z',
#   'Views': '102983',
#   'Likes': '10561',
#   'Comments': '1436'},
#  {'Title': "UNBOXING A 1990's CAMERA IN 2018 !",
#   'Published_date': '2018-09-20T17:29:02Z',
#   'Views': '904978',
#   'Likes': '51416',
#   'Comments': '1978'},
#  {'Title': '5 Cool Android Apps that you Must Try !',
#   'Published_date': '2018-09-16T17:50:53Z',
#   'Views': '839784',
#   'Likes': '37356',
#   'Comments': '2619'},
#  {'Title': 'Don’t Buy These Phones under Rs 12000 ! Paisa Barbad ho jaega!',
#   'Published_date': '2018-09-13T17:11:36Z',
#   'Views': '230921',
#   'Likes': '14999',
#   'Comments': '1719'},
#  {'Title': 'DON’T BUY A SMARTPHONE BEFORE WATCHING THIS VIDEO !',
#   'Published_date': '2018-09-11T18:22:09Z',
#   'Views': '165156',
#   'Likes': '13578',
#   'Comments': '1406'},
#  {'Title': 'Nokia 9 with 5 Cameras , One Plus 6T Leaked , Pub G Insane Update , Iphone Xs ,Jio Free #TechNews',
#   'Published_date': '2018-09-10T18:01:41Z',
#   'Views': '168195',
#   'Likes': '9885',
#   'Comments': '1378'},
#  ...]

# %%
video_data = pd.DataFrame(video_details)
video_data
# Out:
#                                                   Title        Published_date  \
# 0     I Played GTA 5 on Android Smartphone ! *High S...  2024-06-26T18:28:26Z
# 1     This Smartphone is Confusing ! *OnePlus Nord C...  2024-06-24T13:51:41Z
# 2           10 Best Upcoming Smartphones of July 2024 !  2024-06-24T08:52:51Z
# 3                      I Tried this Smart Health Ring !  2024-06-23T07:13:34Z
# 4     Best Deals on Samsung Devices for Students ! *...  2024-06-22T11:12:55Z
# ...                                                 ...                   ...
# 1304  How to Install OFFICIAL Android 5.0 Lollipop o...  2014-12-07T02:13:49Z
# 1305  How to Install Android 5.0 Lollipop(Cm12 Stabl...  2014-11-24T21:35:01Z
# 1306  Android Lollipop Calendar (NEXUS 6) LEAKED , I...  2014-10-24T15:42:55Z
# 1307  Android Lollipop Launcher Installation and Dow...  2014-10-22T14:08:17Z
# 1308  Best INDIAN PC Build for 40K [October 2014]- P...  2014-09-28T18:54:35Z
#
#        Views  Likes Comments
# 0     823747  51572     2446
# 1     335426  14002      757
# 2     666678  24535     1025
# 3     380917  14101      477
# 4     305040  11539      470
# ...      ...    ...      ...
# 1304  198427    946      264
# 1305  120718   1321      187
# 1306   79840   1375      121
# 1307  389711   5577      515
# 1308  674726  22876     2567
#
# [1309 rows x 5 columns]

# %%
# Modifying the DataFrame:
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])

# %%
video_data.dtypes
# Out:
# Title             object
# Published_date    object
# Views              int64
# Likes              int64
# Comments           int64
# dtype: object

# %%
video_data
# Out:
#                                                   Title Published_date  \
# 0     I Played GTA 5 on Android Smartphone ! *High S...     2024-06-26
# 1     This Smartphone is Confusing ! *OnePlus Nord C...     2024-06-24
# 2           10 Best Upcoming Smartphones of July 2024 !     2024-06-24
# 3                      I Tried this Smart Health Ring !     2024-06-23
# 4     Best Deals on Samsung Devices for Students ! *...     2024-06-22
# ...                                                 ...            ...
# 1304  How to Install OFFICIAL Android 5.0 Lollipop o...     2014-12-07
# 1305  How to Install Android 5.0 Lollipop(Cm12 Stabl...     2014-11-24
# 1306  Android Lollipop Calendar (NEXUS 6) LEAKED , I...     2014-10-24
# 1307  Android Lollipop Launcher Installation and Dow...     2014-10-22
# 1308  Best INDIAN PC Build for 40K [October 2014]- P...     2014-09-28
#
#        Views  Likes  Comments
# 0     823747  51572      2446
# 1     335426  14002       757
# 2     666678  24535      1025
# 3     380917  14101       477
# 4     305040  11539       470
# ...      ...    ...       ...
# 1304  198427    946       264
# 1305  120718   1321       187
# 1306   79840   1375       121
# 1307  389711   5577       515
# 1308  674726  22876      2567
#
# [1309 rows x 5 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)
top10_videos
# Out:
#                                                  Title Published_date  \
# 803               5 Majedaar Gadgets I bought Online !     2020-01-26
# 481  I made Custom ₹5,00,000 PC for @souravjoshivlo...     2021-12-02
# 517  Don't Buy Wireless Earphone before Watching th...     2021-09-28
# 360            Nothing Phone (1) *New Midrange King* ?     2022-07-13
# 415          This is My Most Expensive Unboxing! *BMW*     2022-04-06
# 519  7 Majedaar Smartphone Gaming Gadgets you Shoul...     2021-09-24
# 919    Trying 5 Weird SmartPhone Life Hacks #ASLI SACH     2019-04-26
# 393             I Bought a Rs.30000 AI Dancing Robot !     2022-05-09
# 233             Why Rolls Royce Cars Are So Expensive?     2023-03-04
# 405  Don't Buy Smartwatch before Watching this Vide...     2022-04-24
#
#         Views   Likes  Comments
# 803  10134514  518015      7815
# 481   9217939  477350      5563
# 517   8227647  309015      9043
# 360   8080136  352829      6893
# 415   7960383  492244     11653
# 519   7901309  318375      3692
# 919   7746301  356996      5367
# 393   7630597  248634      4213
# 233   7583100  238085      3895
# 405   7406613  226829      5016

# %%
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                   Title Published_date  \
# 0     I Played GTA 5 on Android Smartphone ! *High S...     2024-06-26
# 1     This Smartphone is Confusing ! *OnePlus Nord C...     2024-06-24
# 2           10 Best Upcoming Smartphones of July 2024 !     2024-06-24
# 3                      I Tried this Smart Health Ring !     2024-06-23
# 4     Best Deals on Samsung Devices for Students ! *...     2024-06-22
# ...                                                 ...            ...
# 1304  How to Install OFFICIAL Android 5.0 Lollipop o...     2014-12-07
# 1305  How to Install Android 5.0 Lollipop(Cm12 Stabl...     2014-11-24
# 1306  Android Lollipop Calendar (NEXUS 6) LEAKED , I...     2014-10-24
# 1307  Android Lollipop Launcher Installation and Dow...     2014-10-22
# 1308  Best INDIAN PC Build for 40K [October 2014]- P...     2014-09-28
#
#        Views  Likes  Comments Month
# 0     823747  51572      2446   Jun
# 1     335426  14002       757   Jun
# 2     666678  24535      1025   Jun
# 3     380917  14101       477   Jun
# 4     305040  11539       470   Jun
# ...      ...    ...       ...   ...
# 1304  198427    946       264   Dec
# 1305  120718   1321       187   Nov
# 1306   79840   1375       121   Oct
# 1307  389711   5577       515   Oct
# 1308  674726  22876      2567   Sep
#
# [1309 rows x 6 columns]

# %%
videos_per_month = video_data.groupby('Month', as_index=False).size()

# %%
videos_per_month
# Out:
#    Month  size
# 0    Apr   119
# 1    Aug   110
# 2    Dec   105
# 3    Feb   112
# 4    Jan   108
# 5    Jul   107
# 6    Jun   114
# 7    Mar   125
# 8    May   116
# 9    Nov    84
# 10   Oct   106
# 11   Sep   103

# %%
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)

# %%
videos_per_month = videos_per_month.sort_index()
videos_per_month
# Out:
#       Month  size
# Month
# Jan     Jan   108
# Feb     Feb   112
# Mar     Mar   125
# Apr     Apr   119
# May     May   116
# Jun     Jun   114
# Jul     Jul   107
# Aug     Aug   110
# Sep     Sep   103
# Oct     Oct   106
# Nov     Nov    84
# Dec     Dec   105

# %%
ax3 = sns.barplot(x='Month', y='size' ,data=videos_per_month)

# %%
video_data.to_csv('video_details(Tech Burner).csv')
